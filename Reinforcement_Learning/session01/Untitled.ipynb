# %%
import gym

# %%
env = gym.make('Copy-v0')
env.reset()
env.render()
# Out:
# Total length of input instance: 4, step: 0
# ==========================================
# Observation Tape    :   DCAD
# Output Tape         :
# Targets             :   DCAD

# %%
import gym
env = gym.make("CartPole-v1")
observation = env.reset()
for _ in range(1000):
    env.render()
    action = env.action_space.sample() # your agent here (this takes random actions)
    observation, reward, done, info = env.step(action)

    if done:
        observation = env.reset()
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-4cf91d9fba5b> in <module>
#       3 observation = env.reset()
#       4 for _ in range(1000):
# ----> 5     env.render()
#       6     action = env.action_space.sample() # your agent here (this takes random actions)
#       7     observation, reward, done, info = env.step(action)
#
# ~/.local/lib/python3.7/site-packages/gym/core.py in render(self, mode, **kwargs)
#     247
#     248     def render(self, mode='human', **kwargs):
# --> 249         return self.env.render(mode, **kwargs)
#     250
#     251     def close(self):
#
# ~/.local/lib/python3.7/site-packages/gym/envs/classic_control/cartpole.py in render(self, mode)
#     186         self.poletrans.set_rotation(-x[2])
#     187
# --> 188         return self.viewer.render(return_rgb_array = mode=='rgb_array')
#     189
#     190     def close(self):
#
# ~/.local/lib/python3.7/site-packages/gym/envs/classic_control/rendering.py in render(self, return_rgb_array)
#      90     def render(self, return_rgb_array=False):
#      91         glClearColor(1,1,1,1)
# ---> 92         self.window.clear()
#      93         self.window.switch_to()
#      94         self.window.dispatch_events()
#
# ~/.local/lib/python3.7/site-packages/pyglet/window/__init__.py in clear(self)
#    1226         buffer.  The window must be the active context (see `switch_to`).
#    1227         """
# -> 1228         gl.glClear(gl.GL_COLOR_BUFFER_BIT | gl.GL_DEPTH_BUFFER_BIT)
#    1229
#    1230     def dispatch_event(self, *args):
#
# ~/.local/lib/python3.7/site-packages/pyglet/gl/lib.py in errcheck(result, func, arguments)
#      83     pass
#      84
# ---> 85 def errcheck(result, func, arguments):
#      86     if _debug_gl_trace:
#      87         try:
#
# KeyboardInterrupt:

# %%
import numpy as np
import gym

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import Adam

from rl.agents.cem import CEMAgent
from rl.memory import EpisodeParameterMemory

ENV_NAME = 'CartPole-v0'


# Get the environment and extract the number of actions.
env = gym.make(ENV_NAME)
np.random.seed(123)
env.seed(123)

nb_actions = env.action_space.n
obs_dim = env.observation_space.shape[0]

# Option 1 : Simple model
model = Sequential()
model.add(Flatten(input_shape=(1,) + env.observation_space.shape))
model.add(Dense(nb_actions))
model.add(Activation('softmax'))

# Option 2: deep network
# model = Sequential()
# model.add(Flatten(input_shape=(1,) + env.observation_space.shape))
# model.add(Dense(16))
# model.add(Activation('relu'))
# model.add(Dense(16))
# model.add(Activation('relu'))
# model.add(Dense(16))
# model.add(Activation('relu'))
# model.add(Dense(nb_actions))
# model.add(Activation('softmax'))


print(model.summary())


# Finally, we configure and compile our agent. You can use every built-in Keras optimizer and
# even the metrics!
memory = EpisodeParameterMemory(limit=1000, window_length=1)

cem = CEMAgent(model=model, nb_actions=nb_actions, memory=memory,
               batch_size=50, nb_steps_warmup=2000, train_interval=50, elite_frac=0.05)
cem.compile()

# Okay, now it's time to learn something! We visualize the training here for show, but this
# slows down training quite a lot. You can always safely abort the training prematurely using
# Ctrl + C.
cem.fit(env, nb_steps=100000, visualize=False, verbose=2)

# After training is done, we save the best weights.
cem.save_weights('cem_{}_params.h5f'.format(ENV_NAME), overwrite=True)

# Finally, evaluate our algorithm for 5 episodes.
cem.test(env, nb_episodes=5, visualize=True)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 4)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 10
# _________________________________________________________________
# activation_1 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training for 100000 steps ...
#     13/100000: episode: 1, duration: 1.720s, episode steps: 13, steps per second: 8, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.538 [0.000, 1.000], mean observation: -0.107 [-1.319, 0.772], mean_best_reward: --
#     24/100000: episode: 2, duration: 0.023s, episode steps: 11, steps per second: 481, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.273 [0.000, 1.000], mean observation: 0.151 [-0.941, 1.832], mean_best_reward: --
#     37/100000: episode: 3, duration: 0.025s, episode steps: 13, steps per second: 525, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.231 [0.000, 1.000], mean observation: 0.134 [-1.324, 2.292], mean_best_reward: --
#     51/100000: episode: 4, duration: 0.017s, episode steps: 14, steps per second: 810, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.286 [0.000, 1.000], mean observation: 0.098 [-1.204, 2.050], mean_best_reward: --
#     68/100000: episode: 5, duration: 0.018s, episode steps: 17, steps per second: 951, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.647 [0.000, 1.000], mean observation: -0.087 [-1.945, 1.031], mean_best_reward: --
#     82/100000: episode: 6, duration: 0.013s, episode steps: 14, steps per second: 1045, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.357 [0.000, 1.000], mean observation: 0.116 [-0.788, 1.541], mean_best_reward: --
#    102/100000: episode: 7, duration: 0.020s, episode steps: 20, steps per second: 1012, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.450 [0.000, 1.000], mean observation: 0.086 [-0.747, 1.392], mean_best_reward: --
#    116/100000: episode: 8, duration: 0.014s, episode steps: 14, steps per second: 1023, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.571 [0.000, 1.000], mean observation: -0.084 [-1.549, 0.975], mean_best_reward: --
#    127/100000: episode: 9, duration: 0.010s, episode steps: 11, steps per second: 1120, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.727 [0.000, 1.000], mean observation: -0.091 [-1.886, 1.222], mean_best_reward: --
#    156/100000: episode: 10, duration: 0.021s, episode steps: 29, steps per second: 1369, episode reward: 29.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.655 [0.000, 1.000], mean observation: -0.011 [-2.438, 1.730], mean_best_reward: --
#    168/100000: episode: 11, duration: 0.008s, episode steps: 12, steps per second: 1543, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.667 [0.000, 1.000], mean observation: -0.117 [-1.932, 1.150], mean_best_reward: --
#    183/100000: episode: 12, duration: 0.010s, episode steps: 15, steps per second: 1467, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.267 [0.000, 1.000], mean observation: 0.100 [-1.333, 2.274], mean_best_reward: --
#    196/100000: episode: 13, duration: 0.010s, episode steps: 13, steps per second: 1325, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.154 [0.000, 1.000], mean observation: 0.113 [-1.718, 2.721], mean_best_reward: --
#    208/100000: episode: 14, duration: 0.012s, episode steps: 12, steps per second: 1025, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.250 [0.000, 1.000], mean observation: 0.120 [-1.354, 2.185], mean_best_reward: --
#    217/100000: episode: 15, duration: 0.008s, episode steps: 9, steps per second: 1133, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.111 [0.000, 1.000], mean observation: 0.121 [-1.379, 2.248], mean_best_reward: --
#    227/100000: episode: 16, duration: 0.008s, episode steps: 10, steps per second: 1218, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.900 [0.000, 1.000], mean observation: -0.123 [-2.436, 1.572], mean_best_reward: --
#    242/100000: episode: 17, duration: 0.010s, episode steps: 15, steps per second: 1475, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.600 [0.000, 1.000], mean observation: -0.113 [-1.360, 0.622], mean_best_reward: --
#    256/100000: episode: 18, duration: 0.010s, episode steps: 14, steps per second: 1453, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.286 [0.000, 1.000], mean observation: 0.100 [-1.190, 1.996], mean_best_reward: --
#    270/100000: episode: 19, duration: 0.010s, episode steps: 14, steps per second: 1353, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.643 [0.000, 1.000], mean observation: -0.081 [-1.519, 0.819], mean_best_reward: --
#    283/100000: episode: 20, duration: 0.011s, episode steps: 13, steps per second: 1219, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.692 [0.000, 1.000], mean observation: -0.101 [-1.747, 0.992], mean_best_reward: --
#    299/100000: episode: 21, duration: 0.011s, episode steps: 16, steps per second: 1523, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.438 [0.000, 1.000], mean observation: 0.117 [-0.576, 1.184], mean_best_reward: --
#    314/100000: episode: 22, duration: 0.010s, episode steps: 15, steps per second: 1468, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.400 [0.000, 1.000], mean observation: 0.092 [-0.992, 1.590], mean_best_reward: --
#    354/100000: episode: 23, duration: 0.024s, episode steps: 40, steps per second: 1688, episode reward: 40.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.475 [0.000, 1.000], mean observation: 0.110 [-0.888, 1.608], mean_best_reward: --
#    364/100000: episode: 24, duration: 0.009s, episode steps: 10, steps per second: 1080, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 1.000 [1.000, 1.000], mean observation: -0.136 [-3.099, 1.970], mean_best_reward: --
#    378/100000: episode: 25, duration: 0.010s, episode steps: 14, steps per second: 1404, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.286 [0.000, 1.000], mean observation: 0.066 [-1.383, 2.121], mean_best_reward: --
#    397/100000: episode: 26, duration: 0.012s, episode steps: 19, steps per second: 1537, episode reward: 19.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.737 [0.000, 1.000], mean observation: -0.045 [-2.581, 1.769], mean_best_reward: --
#    428/100000: episode: 27, duration: 0.018s, episode steps: 31, steps per second: 1751, episode reward: 31.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.581 [0.000, 1.000], mean observation: -0.117 [-2.221, 0.996], mean_best_reward: --
#    451/100000: episode: 28, duration: 0.015s, episode steps: 23, steps per second: 1547, episode reward: 23.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.435 [0.000, 1.000], mean observation: 0.053 [-0.844, 1.576], mean_best_reward: --
#    465/100000: episode: 29, duration: 0.010s, episode steps: 14, steps per second: 1403, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.571 [0.000, 1.000], mean observation: -0.071 [-1.293, 0.831], mean_best_reward: --
#    482/100000: episode: 30, duration: 0.011s, episode steps: 17, steps per second: 1489, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.647 [0.000, 1.000], mean observation: -0.072 [-1.722, 1.030], mean_best_reward: --
#    504/100000: episode: 31, duration: 0.016s, episode steps: 22, steps per second: 1413, episode reward: 22.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.591 [0.000, 1.000], mean observation: -0.103 [-1.745, 0.773], mean_best_reward: --
#    529/100000: episode: 32, duration: 0.018s, episode steps: 25, steps per second: 1382, episode reward: 25.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.640 [0.000, 1.000], mean observation: -0.062 [-2.220, 1.329], mean_best_reward: --
#    549/100000: episode: 33, duration: 0.012s, episode steps: 20, steps per second: 1636, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.550 [0.000, 1.000], mean observation: -0.091 [-1.232, 0.804], mean_best_reward: --
#    565/100000: episode: 34, duration: 0.010s, episode steps: 16, steps per second: 1608, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.312 [0.000, 1.000], mean observation: 0.098 [-1.133, 2.087], mean_best_reward: --
#    652/100000: episode: 35, duration: 0.052s, episode steps: 87, steps per second: 1668, episode reward: 87.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.494 [0.000, 1.000], mean observation: -0.164 [-1.532, 1.254], mean_best_reward: --
#    672/100000: episode: 36, duration: 0.014s, episode steps: 20, steps per second: 1439, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.350 [0.000, 1.000], mean observation: 0.053 [-1.201, 1.977], mean_best_reward: --
#    716/100000: episode: 37, duration: 0.030s, episode steps: 44, steps per second: 1458, episode reward: 44.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.568 [0.000, 1.000], mean observation: -0.055 [-2.395, 1.395], mean_best_reward: --
#    728/100000: episode: 38, duration: 0.007s, episode steps: 12, steps per second: 1658, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.333 [0.000, 1.000], mean observation: 0.107 [-0.774, 1.524], mean_best_reward: --
#    742/100000: episode: 39, duration: 0.010s, episode steps: 14, steps per second: 1367, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.786 [0.000, 1.000], mean observation: -0.106 [-2.619, 1.567], mean_best_reward: --
#    795/100000: episode: 40, duration: 0.032s, episode steps: 53, steps per second: 1667, episode reward: 53.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.528 [0.000, 1.000], mean observation: 0.020 [-1.309, 0.945], mean_best_reward: --
#    816/100000: episode: 41, duration: 0.015s, episode steps: 21, steps per second: 1405, episode reward: 21.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.476 [0.000, 1.000], mean observation: -0.069 [-1.439, 0.979], mean_best_reward: --
#    833/100000: episode: 42, duration: 0.013s, episode steps: 17, steps per second: 1358, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.647 [0.000, 1.000], mean observation: -0.106 [-1.847, 0.944], mean_best_reward: --
#    883/100000: episode: 43, duration: 0.030s, episode steps: 50, steps per second: 1673, episode reward: 50.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.520 [0.000, 1.000], mean observation: 0.254 [-0.785, 1.712], mean_best_reward: --
#    893/100000: episode: 44, duration: 0.008s, episode steps: 10, steps per second: 1231, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.200 [0.000, 1.000], mean observation: 0.145 [-1.523, 2.391], mean_best_reward: --
#    924/100000: episode: 45, duration: 0.018s, episode steps: 31, steps per second: 1723, episode reward: 31.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.613 [0.000, 1.000], mean observation: -0.034 [-2.329, 1.418], mean_best_reward: --
#    939/100000: episode: 46, duration: 0.010s, episode steps: 15, steps per second: 1462, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.733 [0.000, 1.000], mean observation: -0.066 [-2.251, 1.410], mean_best_reward: --
#    955/100000: episode: 47, duration: 0.010s, episode steps: 16, steps per second: 1528, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.750 [0.000, 1.000], mean observation: -0.060 [-2.520, 1.606], mean_best_reward: --
#    998/100000: episode: 48, duration: 0.028s, episode steps: 43, steps per second: 1557, episode reward: 43.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.465 [0.000, 1.000], mean observation: 0.003 [-1.143, 1.426], mean_best_reward: --
#   1019/100000: episode: 49, duration: 0.014s, episode steps: 21, steps per second: 1484, episode reward: 21.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.381 [0.000, 1.000], mean observation: 0.076 [-1.190, 2.051], mean_best_reward: --
#   1030/100000: episode: 50, duration: 0.008s, episode steps: 11, steps per second: 1315, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.273 [0.000, 1.000], mean observation: 0.101 [-1.197, 1.872], mean_best_reward: --
#   1045/100000: episode: 51, duration: 0.011s, episode steps: 15, steps per second: 1328, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.333 [0.000, 1.000], mean observation: 0.093 [-0.954, 1.767], mean_best_reward: --
#   1059/100000: episode: 52, duration: 0.010s, episode steps: 14, steps per second: 1382, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.786 [0.000, 1.000], mean observation: -0.119 [-2.666, 1.539], mean_best_reward: --
#   1075/100000: episode: 53, duration: 0.011s, episode steps: 16, steps per second: 1467, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.250 [0.000, 1.000], mean observation: 0.075 [-1.607, 2.480], mean_best_reward: --
#   1091/100000: episode: 54, duration: 0.012s, episode steps: 16, steps per second: 1351, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.688 [0.000, 1.000], mean observation: -0.081 [-2.094, 1.362], mean_best_reward: --
#   1102/100000: episode: 55, duration: 0.008s, episode steps: 11, steps per second: 1356, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.273 [0.000, 1.000], mean observation: 0.113 [-1.155, 1.851], mean_best_reward: --
#   1115/100000: episode: 56, duration: 0.011s, episode steps: 13, steps per second: 1198, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.308 [0.000, 1.000], mean observation: 0.080 [-1.397, 2.108], mean_best_reward: --
#   1126/100000: episode: 57, duration: 0.010s, episode steps: 11, steps per second: 1079, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.727 [0.000, 1.000], mean observation: -0.121 [-2.142, 1.356], mean_best_reward: --
#   1149/100000: episode: 58, duration: 0.015s, episode steps: 23, steps per second: 1582, episode reward: 23.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.522 [0.000, 1.000], mean observation: 0.064 [-0.566, 1.110], mean_best_reward: --
#   1202/100000: episode: 59, duration: 0.031s, episode steps: 53, steps per second: 1707, episode reward: 53.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.509 [0.000, 1.000], mean observation: -0.002 [-1.379, 0.753], mean_best_reward: --
#   1216/100000: episode: 60, duration: 0.009s, episode steps: 14, steps per second: 1554, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.214 [0.000, 1.000], mean observation: 0.093 [-1.609, 2.527], mean_best_reward: --
#   1254/100000: episode: 61, duration: 0.024s, episode steps: 38, steps per second: 1599, episode reward: 38.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.474 [0.000, 1.000], mean observation: -0.061 [-1.214, 0.587], mean_best_reward: --
#   1271/100000: episode: 62, duration: 0.012s, episode steps: 17, steps per second: 1442, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.647 [0.000, 1.000], mean observation: -0.096 [-1.814, 0.995], mean_best_reward: --
#   1370/100000: episode: 63, duration: 0.055s, episode steps: 99, steps per second: 1798, episode reward: 99.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.475 [0.000, 1.000], mean observation: -0.085 [-1.246, 1.047], mean_best_reward: --
#   1389/100000: episode: 64, duration: 0.012s, episode steps: 19, steps per second: 1533, episode reward: 19.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.474 [0.000, 1.000], mean observation: 0.080 [-0.740, 1.199], mean_best_reward: --
#   1459/100000: episode: 65, duration: 0.042s, episode steps: 70, steps per second: 1676, episode reward: 70.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.529 [0.000, 1.000], mean observation: -0.107 [-2.246, 1.724], mean_best_reward: --
#   1475/100000: episode: 66, duration: 0.013s, episode steps: 16, steps per second: 1226, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.625 [0.000, 1.000], mean observation: -0.095 [-1.595, 0.815], mean_best_reward: --
#   1489/100000: episode: 67, duration: 0.009s, episode steps: 14, steps per second: 1559, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.286 [0.000, 1.000], mean observation: 0.078 [-1.181, 1.906], mean_best_reward: --
#   1513/100000: episode: 68, duration: 0.016s, episode steps: 24, steps per second: 1483, episode reward: 24.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.417 [0.000, 1.000], mean observation: 0.076 [-0.776, 1.601], mean_best_reward: --
#   1532/100000: episode: 69, duration: 0.012s, episode steps: 19, steps per second: 1585, episode reward: 19.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.421 [0.000, 1.000], mean observation: 0.069 [-0.780, 1.464], mean_best_reward: --
#   1541/100000: episode: 70, duration: 0.006s, episode steps: 9, steps per second: 1414, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.778 [0.000, 1.000], mean observation: -0.119 [-2.130, 1.384], mean_best_reward: --
#   1568/100000: episode: 71, duration: 0.018s, episode steps: 27, steps per second: 1518, episode reward: 27.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.593 [0.000, 1.000], mean observation: -0.008 [-1.488, 0.931], mean_best_reward: --
#   1577/100000: episode: 72, duration: 0.006s, episode steps: 9, steps per second: 1409, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.222 [0.000, 1.000], mean observation: 0.154 [-1.148, 1.991], mean_best_reward: --
#   1591/100000: episode: 73, duration: 0.010s, episode steps: 14, steps per second: 1455, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.214 [0.000, 1.000], mean observation: 0.086 [-1.613, 2.588], mean_best_reward: --
#   1622/100000: episode: 74, duration: 0.022s, episode steps: 31, steps per second: 1429, episode reward: 31.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.516 [0.000, 1.000], mean observation: 0.160 [-0.540, 1.168], mean_best_reward: --
#   1638/100000: episode: 75, duration: 0.013s, episode steps: 16, steps per second: 1275, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.375 [0.000, 1.000], mean observation: 0.093 [-0.963, 1.647], mean_best_reward: --
#   1651/100000: episode: 76, duration: 0.009s, episode steps: 13, steps per second: 1459, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.462 [0.000, 1.000], mean observation: 0.125 [-0.935, 1.534], mean_best_reward: --
#   1686/100000: episode: 77, duration: 0.022s, episode steps: 35, steps per second: 1562, episode reward: 35.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.400 [0.000, 1.000], mean observation: -0.053 [-1.702, 1.962], mean_best_reward: --
#   1707/100000: episode: 78, duration: 0.018s, episode steps: 21, steps per second: 1147, episode reward: 21.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.619 [0.000, 1.000], mean observation: -0.041 [-1.700, 1.027], mean_best_reward: --
#   1720/100000: episode: 79, duration: 0.009s, episode steps: 13, steps per second: 1396, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.692 [0.000, 1.000], mean observation: -0.094 [-1.725, 1.021], mean_best_reward: --
#   1729/100000: episode: 80, duration: 0.007s, episode steps: 9, steps per second: 1250, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.889 [0.000, 1.000], mean observation: -0.136 [-2.446, 1.607], mean_best_reward: --
#   1741/100000: episode: 81, duration: 0.010s, episode steps: 12, steps per second: 1147, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.250 [0.000, 1.000], mean observation: 0.117 [-1.355, 2.126], mean_best_reward: --
#   1752/100000: episode: 82, duration: 0.009s, episode steps: 11, steps per second: 1171, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.818 [0.000, 1.000], mean observation: -0.125 [-2.329, 1.418], mean_best_reward: --
#   1771/100000: episode: 83, duration: 0.012s, episode steps: 19, steps per second: 1544, episode reward: 19.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.579 [0.000, 1.000], mean observation: -0.084 [-1.328, 0.762], mean_best_reward: --
#   1795/100000: episode: 84, duration: 0.015s, episode steps: 24, steps per second: 1551, episode reward: 24.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.094 [-0.541, 1.014], mean_best_reward: --
#   1814/100000: episode: 85, duration: 0.012s, episode steps: 19, steps per second: 1650, episode reward: 19.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.526 [0.000, 1.000], mean observation: -0.075 [-1.479, 0.966], mean_best_reward: --
#   1847/100000: episode: 86, duration: 0.020s, episode steps: 33, steps per second: 1642, episode reward: 33.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.485 [0.000, 1.000], mean observation: 0.060 [-0.404, 1.106], mean_best_reward: --
#   1859/100000: episode: 87, duration: 0.009s, episode steps: 12, steps per second: 1352, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.167 [0.000, 1.000], mean observation: 0.135 [-1.521, 2.544], mean_best_reward: --
#   1874/100000: episode: 88, duration: 0.012s, episode steps: 15, steps per second: 1273, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.733 [0.000, 1.000], mean observation: -0.100 [-2.323, 1.341], mean_best_reward: --
#   1889/100000: episode: 89, duration: 0.010s, episode steps: 15, steps per second: 1472, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.333 [0.000, 1.000], mean observation: 0.102 [-1.206, 2.017], mean_best_reward: --
#   1899/100000: episode: 90, duration: 0.008s, episode steps: 10, steps per second: 1192, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.700 [0.000, 1.000], mean observation: -0.123 [-1.928, 1.217], mean_best_reward: --
#   1918/100000: episode: 91, duration: 0.013s, episode steps: 19, steps per second: 1453, episode reward: 19.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.684 [0.000, 1.000], mean observation: -0.088 [-2.458, 1.429], mean_best_reward: --
#   1938/100000: episode: 92, duration: 0.014s, episode steps: 20, steps per second: 1390, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.350 [0.000, 1.000], mean observation: 0.070 [-1.205, 2.036], mean_best_reward: --
#   1974/100000: episode: 93, duration: 0.024s, episode steps: 36, steps per second: 1520, episode reward: 36.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.417 [0.000, 1.000], mean observation: 0.064 [-1.197, 2.305], mean_best_reward: --
#   1991/100000: episode: 94, duration: 0.012s, episode steps: 17, steps per second: 1457, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.529 [0.000, 1.000], mean observation: -0.089 [-1.089, 0.573], mean_best_reward: --
#   1999/100000: episode: 95, duration: 0.006s, episode steps: 8, steps per second: 1333, episode reward: 8.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.125 [0.000, 1.000], mean observation: 0.160 [-1.142, 2.028], mean_best_reward: --
#   2009/100000: episode: 96, duration: 0.009s, episode steps: 10, steps per second: 1089, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.100 [0.000, 1.000], mean observation: 0.136 [-1.520, 2.502], mean_best_reward: --
#   2029/100000: episode: 97, duration: 0.014s, episode steps: 20, steps per second: 1417, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: -0.096 [-0.930, 0.391], mean_best_reward: --
#   2043/100000: episode: 98, duration: 0.010s, episode steps: 14, steps per second: 1390, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.286 [0.000, 1.000], mean observation: 0.106 [-1.156, 2.137], mean_best_reward: --
#   2075/100000: episode: 99, duration: 0.020s, episode steps: 32, steps per second: 1576, episode reward: 32.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.531 [0.000, 1.000], mean observation: -0.053 [-1.194, 0.590], mean_best_reward: --
#   2092/100000: episode: 100, duration: 0.011s, episode steps: 17, steps per second: 1509, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.471 [0.000, 1.000], mean observation: 0.044 [-0.827, 1.272], mean_best_reward: --
#   2114/100000: episode: 101, duration: 0.013s, episode steps: 22, steps per second: 1750, episode reward: 22.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.318 [0.000, 1.000], mean observation: 0.050 [-1.562, 2.549], mean_best_reward: 84.500000
#   2180/100000: episode: 102, duration: 0.040s, episode steps: 66, steps per second: 1668, episode reward: 66.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.485 [0.000, 1.000], mean observation: 0.009 [-0.883, 1.322], mean_best_reward: --
#   2190/100000: episode: 103, duration: 0.009s, episode steps: 10, steps per second: 1164, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.800 [0.000, 1.000], mean observation: -0.129 [-2.279, 1.382], mean_best_reward: --
#   2207/100000: episode: 104, duration: 0.011s, episode steps: 17, steps per second: 1547, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.412 [0.000, 1.000], mean observation: 0.094 [-0.605, 1.385], mean_best_reward: --
#   2226/100000: episode: 105, duration: 0.014s, episode steps: 19, steps per second: 1380, episode reward: 19.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.579 [0.000, 1.000], mean observation: -0.100 [-1.629, 0.782], mean_best_reward: --
#   2266/100000: episode: 106, duration: 0.024s, episode steps: 40, steps per second: 1687, episode reward: 40.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.475 [0.000, 1.000], mean observation: 0.074 [-0.785, 1.730], mean_best_reward: --
#   2283/100000: episode: 107, duration: 0.015s, episode steps: 17, steps per second: 1165, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.353 [0.000, 1.000], mean observation: 0.099 [-0.973, 1.775], mean_best_reward: --
#   2317/100000: episode: 108, duration: 0.021s, episode steps: 34, steps per second: 1597, episode reward: 34.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.529 [0.000, 1.000], mean observation: -0.048 [-1.402, 0.767], mean_best_reward: --
#   2344/100000: episode: 109, duration: 0.022s, episode steps: 27, steps per second: 1248, episode reward: 27.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.444 [0.000, 1.000], mean observation: 0.104 [-0.580, 1.590], mean_best_reward: --
#   2362/100000: episode: 110, duration: 0.014s, episode steps: 18, steps per second: 1309, episode reward: 18.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.444 [0.000, 1.000], mean observation: 0.069 [-0.786, 1.346], mean_best_reward: --
#   2391/100000: episode: 111, duration: 0.023s, episode steps: 29, steps per second: 1278, episode reward: 29.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.517 [0.000, 1.000], mean observation: -0.076 [-1.425, 0.781], mean_best_reward: --
#   2435/100000: episode: 112, duration: 0.031s, episode steps: 44, steps per second: 1414, episode reward: 44.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.477 [0.000, 1.000], mean observation: 0.016 [-0.945, 1.310], mean_best_reward: --
#   2463/100000: episode: 113, duration: 0.019s, episode steps: 28, steps per second: 1479, episode reward: 28.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: -0.027 [-1.292, 0.811], mean_best_reward: --
#   2481/100000: episode: 114, duration: 0.013s, episode steps: 18, steps per second: 1382, episode reward: 18.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.071 [-0.441, 0.988], mean_best_reward: --
#   2494/100000: episode: 115, duration: 0.009s, episode steps: 13, steps per second: 1507, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.308 [0.000, 1.000], mean observation: 0.090 [-1.024, 1.779], mean_best_reward: --
#   2528/100000: episode: 116, duration: 0.025s, episode steps: 34, steps per second: 1386, episode reward: 34.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.441 [0.000, 1.000], mean observation: 0.100 [-0.843, 1.975], mean_best_reward: --
#   2558/100000: episode: 117, duration: 0.021s, episode steps: 30, steps per second: 1438, episode reward: 30.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.467 [0.000, 1.000], mean observation: -0.133 [-1.268, 0.538], mean_best_reward: --
#   2588/100000: episode: 118, duration: 0.018s, episode steps: 30, steps per second: 1689, episode reward: 30.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.600 [0.000, 1.000], mean observation: -0.083 [-2.177, 1.162], mean_best_reward: --
#   2615/100000: episode: 119, duration: 0.017s, episode steps: 27, steps per second: 1601, episode reward: 27.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.444 [0.000, 1.000], mean observation: 0.032 [-0.782, 1.420], mean_best_reward: --
#   2639/100000: episode: 120, duration: 0.018s, episode steps: 24, steps per second: 1298, episode reward: 24.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.417 [0.000, 1.000], mean observation: 0.063 [-0.754, 1.564], mean_best_reward: --
#   2662/100000: episode: 121, duration: 0.016s, episode steps: 23, steps per second: 1474, episode reward: 23.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.391 [0.000, 1.000], mean observation: 0.038 [-1.024, 1.750], mean_best_reward: --
#   2671/100000: episode: 122, duration: 0.009s, episode steps: 9, steps per second: 1026, episode reward: 9.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.222 [0.000, 1.000], mean observation: 0.146 [-1.190, 1.936], mean_best_reward: --
#   2687/100000: episode: 123, duration: 0.011s, episode steps: 16, steps per second: 1421, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.250 [0.000, 1.000], mean observation: 0.041 [-1.792, 2.591], mean_best_reward: --
#   2700/100000: episode: 124, duration: 0.011s, episode steps: 13, steps per second: 1133, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.385 [0.000, 1.000], mean observation: 0.109 [-0.602, 1.341], mean_best_reward: --
#   2714/100000: episode: 125, duration: 0.012s, episode steps: 14, steps per second: 1197, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.429 [0.000, 1.000], mean observation: 0.089 [-0.986, 1.599], mean_best_reward: --
#   2737/100000: episode: 126, duration: 0.017s, episode steps: 23, steps per second: 1318, episode reward: 23.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.435 [0.000, 1.000], mean observation: -0.123 [-1.080, 0.621], mean_best_reward: --
#   2757/100000: episode: 127, duration: 0.014s, episode steps: 20, steps per second: 1473, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.400 [0.000, 1.000], mean observation: 0.091 [-0.767, 1.631], mean_best_reward: --
#   2778/100000: episode: 128, duration: 0.019s, episode steps: 21, steps per second: 1109, episode reward: 21.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.476 [0.000, 1.000], mean observation: 0.102 [-0.543, 0.988], mean_best_reward: --
#   2789/100000: episode: 129, duration: 0.008s, episode steps: 11, steps per second: 1374, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.455 [0.000, 1.000], mean observation: 0.105 [-0.996, 1.531], mean_best_reward: --
#   2811/100000: episode: 130, duration: 0.015s, episode steps: 22, steps per second: 1483, episode reward: 22.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.099 [-0.616, 1.094], mean_best_reward: --
#   2938/100000: episode: 131, duration: 0.084s, episode steps: 127, steps per second: 1520, episode reward: 127.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.496 [0.000, 1.000], mean observation: 0.037 [-1.373, 1.797], mean_best_reward: --
#   2970/100000: episode: 132, duration: 0.021s, episode steps: 32, steps per second: 1536, episode reward: 32.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.469 [0.000, 1.000], mean observation: -0.041 [-1.399, 0.988], mean_best_reward: --
#   3030/100000: episode: 133, duration: 0.039s, episode steps: 60, steps per second: 1529, episode reward: 60.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.483 [0.000, 1.000], mean observation: -0.102 [-1.163, 0.801], mean_best_reward: --
#   3084/100000: episode: 134, duration: 0.036s, episode steps: 54, steps per second: 1511, episode reward: 54.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.062 [-0.756, 1.135], mean_best_reward: --
#   3109/100000: episode: 135, duration: 0.017s, episode steps: 25, steps per second: 1451, episode reward: 25.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.440 [0.000, 1.000], mean observation: 0.053 [-0.803, 1.315], mean_best_reward: --
#   3127/100000: episode: 136, duration: 0.014s, episode steps: 18, steps per second: 1272, episode reward: 18.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.556 [0.000, 1.000], mean observation: -0.090 [-1.220, 0.739], mean_best_reward: --
#   3172/100000: episode: 137, duration: 0.031s, episode steps: 45, steps per second: 1454, episode reward: 45.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.489 [0.000, 1.000], mean observation: 0.053 [-0.610, 1.480], mean_best_reward: --
#   3203/100000: episode: 138, duration: 0.021s, episode steps: 31, steps per second: 1488, episode reward: 31.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.452 [0.000, 1.000], mean observation: 0.074 [-0.589, 1.483], mean_best_reward: --
#   3226/100000: episode: 139, duration: 0.015s, episode steps: 23, steps per second: 1561, episode reward: 23.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.522 [0.000, 1.000], mean observation: 0.087 [-0.633, 0.976], mean_best_reward: --
#   3251/100000: episode: 140, duration: 0.017s, episode steps: 25, steps per second: 1445, episode reward: 25.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.520 [0.000, 1.000], mean observation: 0.054 [-0.971, 1.448], mean_best_reward: --
#   3291/100000: episode: 141, duration: 0.029s, episode steps: 40, steps per second: 1370, episode reward: 40.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.525 [0.000, 1.000], mean observation: 0.077 [-0.608, 0.924], mean_best_reward: --
#   3325/100000: episode: 142, duration: 0.022s, episode steps: 34, steps per second: 1566, episode reward: 34.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.559 [0.000, 1.000], mean observation: -0.106 [-1.886, 0.797], mean_best_reward: --
#   3336/100000: episode: 143, duration: 0.010s, episode steps: 11, steps per second: 1152, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.273 [0.000, 1.000], mean observation: 0.162 [-1.136, 2.070], mean_best_reward: --
#   3348/100000: episode: 144, duration: 0.010s, episode steps: 12, steps per second: 1239, episode reward: 12.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.333 [0.000, 1.000], mean observation: 0.095 [-1.195, 1.834], mean_best_reward: --
#   3370/100000: episode: 145, duration: 0.017s, episode steps: 22, steps per second: 1263, episode reward: 22.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.545 [0.000, 1.000], mean observation: -0.062 [-1.278, 0.798], mean_best_reward: --
#   3414/100000: episode: 146, duration: 0.029s, episode steps: 44, steps per second: 1518, episode reward: 44.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.477 [0.000, 1.000], mean observation: -0.026 [-1.175, 1.378], mean_best_reward: --
#   3453/100000: episode: 147, duration: 0.027s, episode steps: 39, steps per second: 1452, episode reward: 39.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.487 [0.000, 1.000], mean observation: 0.053 [-0.728, 1.259], mean_best_reward: --
#   3472/100000: episode: 148, duration: 0.013s, episode steps: 19, steps per second: 1438, episode reward: 19.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.421 [0.000, 1.000], mean observation: 0.086 [-0.982, 1.678], mean_best_reward: --
#   3492/100000: episode: 149, duration: 0.015s, episode steps: 20, steps per second: 1372, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.069 [-0.782, 1.277], mean_best_reward: --
#   3565/100000: episode: 150, duration: 0.051s, episode steps: 73, steps per second: 1442, episode reward: 73.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.493 [0.000, 1.000], mean observation: -0.171 [-1.553, 0.888], mean_best_reward: --
#   3590/100000: episode: 151, duration: 0.018s, episode steps: 25, steps per second: 1391, episode reward: 25.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.440 [0.000, 1.000], mean observation: 0.076 [-0.798, 1.606], mean_best_reward: 53.500000
#   3607/100000: episode: 152, duration: 0.013s, episode steps: 17, steps per second: 1331, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.529 [0.000, 1.000], mean observation: -0.102 [-1.359, 0.742], mean_best_reward: --
#   3639/100000: episode: 153, duration: 0.022s, episode steps: 32, steps per second: 1486, episode reward: 32.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.469 [0.000, 1.000], mean observation: 0.023 [-1.153, 1.540], mean_best_reward: --
#   3663/100000: episode: 154, duration: 0.017s, episode steps: 24, steps per second: 1446, episode reward: 24.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.542 [0.000, 1.000], mean observation: -0.058 [-1.376, 0.764], mean_best_reward: --
#   3682/100000: episode: 155, duration: 0.014s, episode steps: 19, steps per second: 1352, episode reward: 19.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.632 [0.000, 1.000], mean observation: -0.052 [-2.086, 1.378], mean_best_reward: --
#   3720/100000: episode: 156, duration: 0.024s, episode steps: 38, steps per second: 1605, episode reward: 38.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.395 [0.000, 1.000], mean observation: -0.072 [-1.747, 2.032], mean_best_reward: --
#   3745/100000: episode: 157, duration: 0.016s, episode steps: 25, steps per second: 1521, episode reward: 25.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.600 [0.000, 1.000], mean observation: -0.060 [-1.755, 0.967], mean_best_reward: --
#   3755/100000: episode: 158, duration: 0.008s, episode steps: 10, steps per second: 1236, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.700 [0.000, 1.000], mean observation: -0.111 [-1.866, 1.183], mean_best_reward: --
#   3766/100000: episode: 159, duration: 0.008s, episode steps: 11, steps per second: 1464, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.727 [0.000, 1.000], mean observation: -0.101 [-2.058, 1.396], mean_best_reward: --
#   3801/100000: episode: 160, duration: 0.026s, episode steps: 35, steps per second: 1352, episode reward: 35.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.629 [0.000, 1.000], mean observation: 0.038 [-2.362, 1.975], mean_best_reward: --
#   3826/100000: episode: 161, duration: 0.017s, episode steps: 25, steps per second: 1498, episode reward: 25.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.520 [0.000, 1.000], mean observation: 0.132 [-0.402, 0.908], mean_best_reward: --
#   3849/100000: episode: 162, duration: 0.016s, episode steps: 23, steps per second: 1453, episode reward: 23.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.522 [0.000, 1.000], mean observation: 0.113 [-0.567, 0.975], mean_best_reward: --
#   3871/100000: episode: 163, duration: 0.016s, episode steps: 22, steps per second: 1388, episode reward: 22.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.636 [0.000, 1.000], mean observation: -0.051 [-2.121, 1.329], mean_best_reward: --
#   3909/100000: episode: 164, duration: 0.025s, episode steps: 38, steps per second: 1505, episode reward: 38.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.553 [0.000, 1.000], mean observation: -0.015 [-1.596, 0.822], mean_best_reward: --
#   3942/100000: episode: 165, duration: 0.022s, episode steps: 33, steps per second: 1518, episode reward: 33.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.545 [0.000, 1.000], mean observation: -0.107 [-1.777, 0.599], mean_best_reward: --
#   3981/100000: episode: 166, duration: 0.026s, episode steps: 39, steps per second: 1490, episode reward: 39.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.590 [0.000, 1.000], mean observation: 0.081 [-1.428, 1.471], mean_best_reward: --
#   4006/100000: episode: 167, duration: 0.017s, episode steps: 25, steps per second: 1496, episode reward: 25.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.680 [0.000, 1.000], mean observation: -0.042 [-2.722, 1.769], mean_best_reward: --
#   4030/100000: episode: 168, duration: 0.015s, episode steps: 24, steps per second: 1629, episode reward: 24.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: -0.068 [-1.218, 0.824], mean_best_reward: --
#   4048/100000: episode: 169, duration: 0.013s, episode steps: 18, steps per second: 1341, episode reward: 18.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.333 [0.000, 1.000], mean observation: 0.058 [-1.376, 2.131], mean_best_reward: --
#   4079/100000: episode: 170, duration: 0.019s, episode steps: 31, steps per second: 1613, episode reward: 31.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.613 [0.000, 1.000], mean observation: -0.022 [-2.210, 1.391], mean_best_reward: --
#   4093/100000: episode: 171, duration: 0.010s, episode steps: 14, steps per second: 1427, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.085 [-1.014, 1.498], mean_best_reward: --
#   4111/100000: episode: 172, duration: 0.011s, episode steps: 18, steps per second: 1596, episode reward: 18.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.611 [0.000, 1.000], mean observation: -0.062 [-1.765, 1.027], mean_best_reward: --
#   4162/100000: episode: 173, duration: 0.031s, episode steps: 51, steps per second: 1628, episode reward: 51.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.569 [0.000, 1.000], mean observation: 0.015 [-1.861, 1.399], mean_best_reward: --
#   4188/100000: episode: 174, duration: 0.020s, episode steps: 26, steps per second: 1279, episode reward: 26.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: -0.082 [-1.192, 0.729], mean_best_reward: --
#   4202/100000: episode: 175, duration: 0.010s, episode steps: 14, steps per second: 1448, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.357 [0.000, 1.000], mean observation: 0.115 [-0.965, 1.841], mean_best_reward: --
#   4218/100000: episode: 176, duration: 0.012s, episode steps: 16, steps per second: 1372, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.562 [0.000, 1.000], mean observation: -0.118 [-1.314, 0.764], mean_best_reward: --
#   4229/100000: episode: 177, duration: 0.008s, episode steps: 11, steps per second: 1296, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.818 [0.000, 1.000], mean observation: -0.115 [-2.529, 1.585], mean_best_reward: --
#   4239/100000: episode: 178, duration: 0.008s, episode steps: 10, steps per second: 1250, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.300 [0.000, 1.000], mean observation: 0.131 [-0.999, 1.712], mean_best_reward: --
#   4255/100000: episode: 179, duration: 0.013s, episode steps: 16, steps per second: 1258, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.625 [0.000, 1.000], mean observation: -0.070 [-2.044, 1.362], mean_best_reward: --
#   4301/100000: episode: 180, duration: 0.029s, episode steps: 46, steps per second: 1601, episode reward: 46.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.457 [0.000, 1.000], mean observation: -0.006 [-0.944, 1.530], mean_best_reward: --
#   4322/100000: episode: 181, duration: 0.013s, episode steps: 21, steps per second: 1583, episode reward: 21.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.524 [0.000, 1.000], mean observation: -0.066 [-1.306, 0.813], mean_best_reward: --
#   4342/100000: episode: 182, duration: 0.013s, episode steps: 20, steps per second: 1483, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.450 [0.000, 1.000], mean observation: 0.051 [-0.822, 1.301], mean_best_reward: --
#   4358/100000: episode: 183, duration: 0.011s, episode steps: 16, steps per second: 1421, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.688 [0.000, 1.000], mean observation: -0.102 [-2.187, 1.171], mean_best_reward: --
#   4372/100000: episode: 184, duration: 0.009s, episode steps: 14, steps per second: 1613, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.571 [0.000, 1.000], mean observation: -0.115 [-1.469, 0.743], mean_best_reward: --
#   4389/100000: episode: 185, duration: 0.012s, episode steps: 17, steps per second: 1443, episode reward: 17.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.588 [0.000, 1.000], mean observation: -0.054 [-1.734, 1.187], mean_best_reward: --
#   4418/100000: episode: 186, duration: 0.025s, episode steps: 29, steps per second: 1146, episode reward: 29.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.448 [0.000, 1.000], mean observation: 0.056 [-0.797, 1.522], mean_best_reward: --
#   4429/100000: episode: 187, duration: 0.009s, episode steps: 11, steps per second: 1232, episode reward: 11.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.818 [0.000, 1.000], mean observation: -0.133 [-2.365, 1.384], mean_best_reward: --
#   4439/100000: episode: 188, duration: 0.008s, episode steps: 10, steps per second: 1200, episode reward: 10.000, mean reward: 1.000 [1.000, 1.000], mean action: 1.000 [1.000, 1.000], mean observation: -0.153 [-3.092, 1.915], mean_best_reward: --
#   4470/100000: episode: 189, duration: 0.022s, episode steps: 31, steps per second: 1389, episode reward: 31.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.452 [0.000, 1.000], mean observation: 0.050 [-0.992, 1.442], mean_best_reward: --
#   4486/100000: episode: 190, duration: 0.013s, episode steps: 16, steps per second: 1270, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.688 [0.000, 1.000], mean observation: -0.095 [-2.247, 1.396], mean_best_reward: --
# ...
#  96957/100000: episode: 2728, duration: 0.021s, episode steps: 34, steps per second: 1646, episode reward: 34.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: -0.040 [-1.134, 0.642], mean_best_reward: --
#  96986/100000: episode: 2729, duration: 0.017s, episode steps: 29, steps per second: 1742, episode reward: 29.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.552 [0.000, 1.000], mean observation: 0.103 [-0.630, 0.942], mean_best_reward: --
#  97029/100000: episode: 2730, duration: 0.024s, episode steps: 43, steps per second: 1778, episode reward: 43.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.488 [0.000, 1.000], mean observation: -0.169 [-1.398, 0.550], mean_best_reward: --
#  97052/100000: episode: 2731, duration: 0.014s, episode steps: 23, steps per second: 1644, episode reward: 23.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.522 [0.000, 1.000], mean observation: 0.103 [-0.560, 0.975], mean_best_reward: --
#  97181/100000: episode: 2732, duration: 0.067s, episode steps: 129, steps per second: 1913, episode reward: 129.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.496 [0.000, 1.000], mean observation: -0.198 [-1.247, 0.808], mean_best_reward: --
#  97267/100000: episode: 2733, duration: 0.046s, episode steps: 86, steps per second: 1868, episode reward: 86.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.477 [0.000, 1.000], mean observation: -0.164 [-1.084, 0.586], mean_best_reward: --
#  97341/100000: episode: 2734, duration: 0.044s, episode steps: 74, steps per second: 1692, episode reward: 74.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.541 [0.000, 1.000], mean observation: 0.157 [-0.790, 1.074], mean_best_reward: --
#  97365/100000: episode: 2735, duration: 0.015s, episode steps: 24, steps per second: 1612, episode reward: 24.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.458 [0.000, 1.000], mean observation: 0.078 [-0.609, 1.333], mean_best_reward: --
#  97434/100000: episode: 2736, duration: 0.039s, episode steps: 69, steps per second: 1786, episode reward: 69.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.522 [0.000, 1.000], mean observation: 0.161 [-1.528, 1.708], mean_best_reward: --
#  97479/100000: episode: 2737, duration: 0.026s, episode steps: 45, steps per second: 1730, episode reward: 45.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.467 [0.000, 1.000], mean observation: -0.215 [-1.241, 0.998], mean_best_reward: --
#  97553/100000: episode: 2738, duration: 0.043s, episode steps: 74, steps per second: 1714, episode reward: 74.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: -0.103 [-1.296, 0.933], mean_best_reward: --
#  97573/100000: episode: 2739, duration: 0.012s, episode steps: 20, steps per second: 1600, episode reward: 20.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.550 [0.000, 1.000], mean observation: -0.066 [-1.105, 0.618], mean_best_reward: --
#  97607/100000: episode: 2740, duration: 0.019s, episode steps: 34, steps per second: 1784, episode reward: 34.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: -0.135 [-1.195, 0.748], mean_best_reward: --
#  97630/100000: episode: 2741, duration: 0.013s, episode steps: 23, steps per second: 1757, episode reward: 23.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.478 [0.000, 1.000], mean observation: 0.062 [-0.810, 1.456], mean_best_reward: --
#  97665/100000: episode: 2742, duration: 0.020s, episode steps: 35, steps per second: 1714, episode reward: 35.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.514 [0.000, 1.000], mean observation: 0.127 [-0.964, 1.450], mean_best_reward: --
#  97717/100000: episode: 2743, duration: 0.036s, episode steps: 52, steps per second: 1452, episode reward: 52.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.481 [0.000, 1.000], mean observation: -0.130 [-1.021, 0.668], mean_best_reward: --
#  97742/100000: episode: 2744, duration: 0.015s, episode steps: 25, steps per second: 1649, episode reward: 25.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.400 [0.000, 1.000], mean observation: 0.038 [-1.137, 1.711], mean_best_reward: --
#  97827/100000: episode: 2745, duration: 0.046s, episode steps: 85, steps per second: 1830, episode reward: 85.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.518 [0.000, 1.000], mean observation: 0.077 [-0.599, 0.861], mean_best_reward: --
#  97840/100000: episode: 2746, duration: 0.009s, episode steps: 13, steps per second: 1516, episode reward: 13.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.615 [0.000, 1.000], mean observation: -0.103 [-1.723, 1.158], mean_best_reward: --
#  97863/100000: episode: 2747, duration: 0.015s, episode steps: 23, steps per second: 1576, episode reward: 23.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.565 [0.000, 1.000], mean observation: -0.067 [-1.378, 0.814], mean_best_reward: --
#  97905/100000: episode: 2748, duration: 0.024s, episode steps: 42, steps per second: 1774, episode reward: 42.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: -0.081 [-1.531, 0.717], mean_best_reward: --
#  97929/100000: episode: 2749, duration: 0.014s, episode steps: 24, steps per second: 1751, episode reward: 24.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.098 [-0.396, 1.128], mean_best_reward: --
#  97966/100000: episode: 2750, duration: 0.021s, episode steps: 37, steps per second: 1728, episode reward: 37.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.486 [0.000, 1.000], mean observation: 0.085 [-0.623, 1.285], mean_best_reward: --
#  97981/100000: episode: 2751, duration: 0.012s, episode steps: 15, steps per second: 1280, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.667 [0.000, 1.000], mean observation: -0.067 [-1.640, 1.021], mean_best_reward: 131.500000
#  98003/100000: episode: 2752, duration: 0.013s, episode steps: 22, steps per second: 1688, episode reward: 22.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.084 [-0.980, 1.464], mean_best_reward: --
#  98087/100000: episode: 2753, duration: 0.048s, episode steps: 84, steps per second: 1750, episode reward: 84.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.452 [0.000, 1.000], mean observation: -0.225 [-1.822, 0.601], mean_best_reward: --
#  98141/100000: episode: 2754, duration: 0.030s, episode steps: 54, steps per second: 1773, episode reward: 54.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.033 [-0.731, 1.147], mean_best_reward: --
#  98166/100000: episode: 2755, duration: 0.015s, episode steps: 25, steps per second: 1633, episode reward: 25.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.480 [0.000, 1.000], mean observation: 0.119 [-0.375, 1.166], mean_best_reward: --
#  98256/100000: episode: 2756, duration: 0.051s, episode steps: 90, steps per second: 1774, episode reward: 90.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.544 [0.000, 1.000], mean observation: 0.246 [-0.952, 1.650], mean_best_reward: --
#  98358/100000: episode: 2757, duration: 0.055s, episode steps: 102, steps per second: 1865, episode reward: 102.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.451 [0.000, 1.000], mean observation: -0.241 [-2.617, 1.946], mean_best_reward: --
#  98380/100000: episode: 2758, duration: 0.016s, episode steps: 22, steps per second: 1393, episode reward: 22.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: -0.102 [-1.123, 0.430], mean_best_reward: --
#  98414/100000: episode: 2759, duration: 0.021s, episode steps: 34, steps per second: 1602, episode reward: 34.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: 0.073 [-0.424, 1.152], mean_best_reward: --
#  98459/100000: episode: 2760, duration: 0.031s, episode steps: 45, steps per second: 1451, episode reward: 45.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.467 [0.000, 1.000], mean observation: -0.123 [-0.747, 0.421], mean_best_reward: --
#  98494/100000: episode: 2761, duration: 0.020s, episode steps: 35, steps per second: 1734, episode reward: 35.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.514 [0.000, 1.000], mean observation: -0.102 [-1.570, 0.470], mean_best_reward: --
#  98568/100000: episode: 2762, duration: 0.040s, episode steps: 74, steps per second: 1830, episode reward: 74.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.541 [0.000, 1.000], mean observation: 0.244 [-0.701, 1.432], mean_best_reward: --
#  98605/100000: episode: 2763, duration: 0.021s, episode steps: 37, steps per second: 1800, episode reward: 37.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.514 [0.000, 1.000], mean observation: -0.039 [-0.967, 0.579], mean_best_reward: --
#  98679/100000: episode: 2764, duration: 0.043s, episode steps: 74, steps per second: 1717, episode reward: 74.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.554 [0.000, 1.000], mean observation: 0.249 [-0.949, 1.431], mean_best_reward: --
#  98710/100000: episode: 2765, duration: 0.017s, episode steps: 31, steps per second: 1826, episode reward: 31.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.516 [0.000, 1.000], mean observation: 0.057 [-0.605, 0.919], mean_best_reward: --
#  98757/100000: episode: 2766, duration: 0.028s, episode steps: 47, steps per second: 1702, episode reward: 47.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.532 [0.000, 1.000], mean observation: 0.024 [-0.959, 1.232], mean_best_reward: --
#  98820/100000: episode: 2767, duration: 0.037s, episode steps: 63, steps per second: 1708, episode reward: 63.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.540 [0.000, 1.000], mean observation: 0.197 [-0.507, 1.129], mean_best_reward: --
#  98841/100000: episode: 2768, duration: 0.015s, episode steps: 21, steps per second: 1393, episode reward: 21.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.571 [0.000, 1.000], mean observation: -0.090 [-1.621, 0.780], mean_best_reward: --
#  98888/100000: episode: 2769, duration: 0.028s, episode steps: 47, steps per second: 1703, episode reward: 47.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.489 [0.000, 1.000], mean observation: -0.048 [-1.077, 0.852], mean_best_reward: --
#  98931/100000: episode: 2770, duration: 0.024s, episode steps: 43, steps per second: 1801, episode reward: 43.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.512 [0.000, 1.000], mean observation: -0.085 [-1.500, 0.662], mean_best_reward: --
#  99019/100000: episode: 2771, duration: 0.047s, episode steps: 88, steps per second: 1873, episode reward: 88.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.523 [0.000, 1.000], mean observation: 0.040 [-0.867, 1.244], mean_best_reward: --
#  99080/100000: episode: 2772, duration: 0.035s, episode steps: 61, steps per second: 1723, episode reward: 61.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.459 [0.000, 1.000], mean observation: -0.200 [-1.132, 0.606], mean_best_reward: --
#  99111/100000: episode: 2773, duration: 0.018s, episode steps: 31, steps per second: 1766, episode reward: 31.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.548 [0.000, 1.000], mean observation: 0.107 [-0.599, 0.997], mean_best_reward: --
#  99185/100000: episode: 2774, duration: 0.042s, episode steps: 74, steps per second: 1770, episode reward: 74.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.514 [0.000, 1.000], mean observation: -0.046 [-1.455, 0.787], mean_best_reward: --
#  99282/100000: episode: 2775, duration: 0.055s, episode steps: 97, steps per second: 1775, episode reward: 97.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.505 [0.000, 1.000], mean observation: 0.005 [-0.599, 1.044], mean_best_reward: --
#  99297/100000: episode: 2776, duration: 0.011s, episode steps: 15, steps per second: 1425, episode reward: 15.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.467 [0.000, 1.000], mean observation: 0.119 [-0.369, 1.089], mean_best_reward: --
#  99367/100000: episode: 2777, duration: 0.039s, episode steps: 70, steps per second: 1781, episode reward: 70.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.543 [0.000, 1.000], mean observation: 0.165 [-0.623, 1.290], mean_best_reward: --
#  99381/100000: episode: 2778, duration: 0.009s, episode steps: 14, steps per second: 1543, episode reward: 14.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.571 [0.000, 1.000], mean observation: -0.093 [-1.327, 0.807], mean_best_reward: --
#  99441/100000: episode: 2779, duration: 0.034s, episode steps: 60, steps per second: 1766, episode reward: 60.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.517 [0.000, 1.000], mean observation: 0.130 [-0.633, 1.062], mean_best_reward: --
#  99457/100000: episode: 2780, duration: 0.010s, episode steps: 16, steps per second: 1617, episode reward: 16.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.562 [0.000, 1.000], mean observation: -0.079 [-1.378, 0.773], mean_best_reward: --
#  99564/100000: episode: 2781, duration: 0.064s, episode steps: 107, steps per second: 1681, episode reward: 107.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.505 [0.000, 1.000], mean observation: 0.025 [-0.715, 1.158], mean_best_reward: --
#  99636/100000: episode: 2782, duration: 0.042s, episode steps: 72, steps per second: 1731, episode reward: 72.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.542 [0.000, 1.000], mean observation: 0.204 [-0.835, 1.467], mean_best_reward: --
#  99701/100000: episode: 2783, duration: 0.036s, episode steps: 65, steps per second: 1791, episode reward: 65.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.523 [0.000, 1.000], mean observation: 0.137 [-0.914, 1.014], mean_best_reward: --
#  99722/100000: episode: 2784, duration: 0.013s, episode steps: 21, steps per second: 1661, episode reward: 21.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.429 [0.000, 1.000], mean observation: 0.039 [-0.830, 1.441], mean_best_reward: --
#  99751/100000: episode: 2785, duration: 0.016s, episode steps: 29, steps per second: 1767, episode reward: 29.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.483 [0.000, 1.000], mean observation: -0.049 [-1.362, 0.925], mean_best_reward: --
#  99814/100000: episode: 2786, duration: 0.035s, episode steps: 63, steps per second: 1791, episode reward: 63.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.540 [0.000, 1.000], mean observation: 0.177 [-0.578, 1.250], mean_best_reward: --
#  99844/100000: episode: 2787, duration: 0.018s, episode steps: 30, steps per second: 1710, episode reward: 30.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.600 [0.000, 1.000], mean observation: -0.088 [-2.291, 1.165], mean_best_reward: --
#  99874/100000: episode: 2788, duration: 0.018s, episode steps: 30, steps per second: 1650, episode reward: 30.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.500 [0.000, 1.000], mean observation: -0.143 [-1.373, 0.573], mean_best_reward: --
#  99924/100000: episode: 2789, duration: 0.029s, episode steps: 50, steps per second: 1714, episode reward: 50.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.520 [0.000, 1.000], mean observation: 0.032 [-1.017, 1.290], mean_best_reward: --
#  99952/100000: episode: 2790, duration: 0.018s, episode steps: 28, steps per second: 1570, episode reward: 28.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.464 [0.000, 1.000], mean observation: -0.030 [-1.207, 1.480], mean_best_reward: --
# done, took 64.467 seconds
# Testing for 5 episodes ...
# Episode 1: reward: 138.000, steps: 138
# Episode 2: reward: 111.000, steps: 111
# Episode 3: reward: 107.000, steps: 107
# Episode 4: reward: 97.000, steps: 97
# Episode 5: reward: 190.000, steps: 190

# %%
import gym
env = gym.make('CartPole-v0')
env.reset()
for _ in range(1000):
    env.render()
    env.step(env.action_space.sample()) # take a random action
env.close()
