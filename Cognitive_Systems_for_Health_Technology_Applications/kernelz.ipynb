# %%
import os

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import spacy

import keras
from keras import layers
from keras.utils import to_categorical

from html import unescape
# Out:
# Using TensorFlow backend.

# %%
# !python -m spacy download en_core_web_lg

import spacy
nlp = spacy.load('en_core_web_lg')
# Out:
# Requirement already satisfied: en_core_web_lg==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.0.0/en_core_web_lg-2.0.0.tar.gz#egg=en_core_web_lg==2.0.0 in /opt/conda/lib/python3.6/site-packages (2.0.0)
#
#     Linking successful
#     /opt/conda/lib/python3.6/site-packages/en_core_web_lg -->
#     /opt/conda/lib/python3.6/site-packages/spacy/data/en_core_web_lg
#
#     You can now load the model via spacy.load('en_core_web_lg')

# %%
### plotting ###
# prettier and larger basic graphs
sns.set(rc={
    'figure.figsize':(18,8),
    'axes.titlesize':14,
})

### pandas ###
# no need to see many decimal places and makes nicer horizontal fits :-)
pd.options.display.float_format = '{:.3f}'.format
# pd.options.display.precision = 3
# make the tables more compact vertically, too
pd.options.display.max_rows = 20

### numpy ###
# same as for pandas - max. 3 decimal places
np.set_printoptions(formatter={'float_kind':'{:.3f}'.format})
# np.set_printoptions(precision=3)

# %%
print(os.listdir("../input"))
# Out:
# ['drugsComTest_raw.csv', 'drugsComTrain_raw.csv']

# %%
reviews_df = pd.read_csv('../input/drugsComTrain_raw.csv').sample(30000, random_state=0)
reviews_df
# Out:
#         uniqueID     ...     usefulCount
# 137738     48134     ...              12
# 125778     43221     ...               1
# 26647     109628     ...               7
# 89592      90397     ...               1
# 83605       6631     ...              10
# 105081     35875     ...              54
# 15387     170182     ...              16
# 112403    164074     ...              12
# 92541     123067     ...               8
# 30749      94851     ...              28
# ...          ...     ...             ...
# 139165     76245     ...               3
# 157269    117814     ...               4
# 114311    113882     ...              35
# 5930       29489     ...              66
# 137450    144627     ...               5
# 113766     99243     ...               2
# 102242      3811     ...               9
# 160636    211800     ...              44
# 160944    149680     ...               4
# 126706    192853     ...               2
#
# [30000 rows x 7 columns]

# %%
def clean_review(text):
    # replace HTML escaped characters and strip outer quotes and spaces
    return unescape(
        text.strip(' "\'').replace('/', ' ')
    )

reviews_df.review = reviews_df.review.apply(clean_review)

# %%
reviews_nlp = nlp.pipe(
    texts=reviews_df.review.values,
    disable=['tagger', 'parser', 'ner'],
)

reviews_df['review_vec_seq'] = None
reviews_df['review_vector'] = None

for index, review in zip(reviews_df.index, reviews_nlp):
    # transform the review to a sequence of vectors
    vec_seq = [
        token.vector if token.has_vector else nlp.vocab[token.lemma_].vector
        for token in review
    ]
    reviews_df.at[index, 'review_vec_seq'] = vec_seq
    reviews_df.at[index, 'review_vector'] = review.vector

# %%
# Check the new data
reviews_df.sample(20)
# Out:
#         uniqueID                        ...                                                              review_vector
# 13209       9783                        ...                          [-0.1400638, 0.28034598, 0.006110591, -0.35610...
# 140168    102653                        ...                          [-0.034280233, 0.18095352, -0.08797183, -0.171...
# 103055     39134                        ...                          [-0.0021355876, 0.2577304, -0.14841059, -0.062...
# 26013      41889                        ...                          [-0.022818482, 0.20389454, -0.15870778, -0.005...
# 19495      21755                        ...                          [0.012822997, 0.33343634, -0.21424255, -0.0322...
# 103673     84177                        ...                          [-0.02751798, 0.22323732, -0.25085485, -0.1036...
# 57158     215793                        ...                          [-0.032858543, 0.2070295, -0.1623073, -0.04492...
# 25693      96526                        ...                          [-0.03223112, 0.20946532, -0.17139983, -0.0631...
# 145963     18651                        ...                          [-0.0033713959, 0.21918283, -0.19004488, -0.06...
# 67625      77439                        ...                          [-0.048446137, 0.21259525, -0.2201448, -0.0527...
# 81721     110360                        ...                          [-0.032412942, 0.2031663, -0.23248477, -0.0677...
# 39772      33441                        ...                          [-0.034132946, 0.1914055, -0.18382467, -0.0564...
# 102217    206436                        ...                          [-0.04505104, 0.19619761, -0.20902574, -0.0672...
# 21610     159424                        ...                          [-0.049155436, 0.16471787, -0.10545008, -0.131...
# 86108     171950                        ...                          [-0.040061336, 0.20542833, -0.20822012, -0.011...
# 113589    175657                        ...                          [-0.094744034, 0.19152609, -0.22605908, -0.155...
# 103707     37883                        ...                          [-0.07758362, 0.17471151, -0.19136672, -0.0695...
# 28117     217951                        ...                          [0.030105641, 0.1974958, -0.12779494, -0.17750...
# 36433     196728                        ...                          [-0.018317528, 0.20870836, -0.24774286, -0.084...
# 95996      49103                        ...                          [-0.050131902, 0.21004453, -0.1791643, -0.0642...
#
# [20 rows x 9 columns]

# %%
MAX_SEQUENCE_LENGTH = 200
VOCABULARY_SIZE = 2000

# %%
sequence_lenghts = np.array([len(s) for s in reviews_df.review_vec_seq])

# %%
sns.distplot(
    sequence_lenghts,
    hist_kws=dict(label='Histogram'),
    kde=True,
    kde_kws=dict(label='Kernel Density'),
    rug=True,
    norm_hist=False,
    rug_kws=dict(color='orangered', label='Sample'),
    axlabel='Sequence Lenght',
)
plt.axvline(x=MAX_SEQUENCE_LENGTH, color='yellowgreen', label='Sequence Cutoff Lenght')
plt.ylabel('Density')
plt.legend();
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(sequence_lenghts, kde=False)
plt.gca().set_yscale('log')
plt.axvline(x=MAX_SEQUENCE_LENGTH, color='yellowgreen');
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sum(sequence_lenghts > MAX_SEQUENCE_LENGTH)/len(sequence_lenghts)
# Out:
# 0.0023333333333333335

# %%
x_train = keras.preprocessing.sequence.pad_sequences(reviews_df.review_vec_seq, maxlen=MAX_SEQUENCE_LENGTH)
y_train = reviews_df.rating

# %%
# plotting

def plot_history(history, skip_first_n_epochs=0):
    """Show information about the training"""
    
    # plot every train-valid metric pair separately
    for metric in history:
        if not metric.startswith('val_'):
            x = np.arange(len(history[metric]))+1

            y_train = history[metric][skip_first_n_epochs:]
            y_valid = history['val_'+metric][skip_first_n_epochs:]

            # make the plots
            plt.plot(x, y_train)
            plt.plot(x, y_valid)

            # add a legend
            plt.legend([metric, 'val_'+metric], fontsize='large')

            # title with min/max stats
            plt.title(
                f'{metric.upper()} - '
                f'min/max [train: {min(y_train):.3f}/{max(y_train):.3f}, '
                f'valid: {min(y_valid):.3f}/{max(y_valid):.3f}]'
            )
            
            # label and show
            plt.xlabel('epoch')
            plt.show()

# %%
x_train.shape
# Out:
# (30000, 200, 300)

# %%
model = keras.models.Sequential()
model.add(layers.InputLayer(x_train.shape[1:]))
model.add(layers.CuDNNLSTM(128, return_sequences=True))
model.add(layers.CuDNNLSTM(64, return_sequences=True))
model.add(layers.Flatten())
model.add(layers.BatchNormalization())
model.add(layers.Dense(16, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dense(1, activation='linear'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cu_dnnlstm_17 (CuDNNLSTM)    (None, 200, 128)          220160
# _________________________________________________________________
# cu_dnnlstm_18 (CuDNNLSTM)    (None, 200, 64)           49664
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 12800)             51200
# _________________________________________________________________
# dense_18 (Dense)             (None, 16)                204816
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 16)                64
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 525,921
# Trainable params: 500,289
# Non-trainable params: 25,632
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='mae',
    metrics=['mae', 'mse'],
)

# %%
history = model.fit(
    x=x_train,
    y=y_train,
    batch_size=256,
    epochs=20,
    verbose=1,
    validation_split=0.25,
    callbacks=[
        keras.callbacks.ModelCheckpoint(
            'model-epoch_{epoch:02d}-val_loss_{val_loss:.2f}.hdf5',
            monitor='val_loss',
            verbose=0,
            save_best_only=True,
            save_weights_only=False,
            mode='auto',
            period=1,
        ),
    ],
)

plot_history(history.history)
# Out:
# Train on 22500 samples, validate on 7500 samples
# Epoch 1/20
# 22500/22500 [==============================] - 25s 1ms/step - loss: 6.7355 - mean_absolute_error: 6.7355 - mean_squared_error: 56.5676 - val_loss: 5.8068 - val_mean_absolute_error: 5.8068 - val_mean_squared_error: 43.6992
# Epoch 2/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 5.9516 - mean_absolute_error: 5.9516 - mean_squared_error: 45.7477 - val_loss: 6.5636 - val_mean_absolute_error: 6.5636 - val_mean_squared_error: 53.6190
# Epoch 3/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 4.9399 - mean_absolute_error: 4.9399 - mean_squared_error: 32.4268 - val_loss: 5.6922 - val_mean_absolute_error: 5.6922 - val_mean_squared_error: 41.6810
# Epoch 4/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 3.7829 - mean_absolute_error: 3.7829 - mean_squared_error: 19.5914 - val_loss: 2.8143 - val_mean_absolute_error: 2.8143 - val_mean_squared_error: 11.5256
# Epoch 5/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 2.8199 - mean_absolute_error: 2.8199 - mean_squared_error: 11.5580 - val_loss: 6.8664 - val_mean_absolute_error: 6.8664 - val_mean_squared_error: 61.9517
# Epoch 6/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 2.3253 - mean_absolute_error: 2.3253 - mean_squared_error: 8.8683 - val_loss: 5.6655 - val_mean_absolute_error: 5.6655 - val_mean_squared_error: 42.4715
# Epoch 7/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 2.1805 - mean_absolute_error: 2.1805 - mean_squared_error: 8.5359 - val_loss: 2.4790 - val_mean_absolute_error: 2.4790 - val_mean_squared_error: 11.4760
# Epoch 8/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 2.1079 - mean_absolute_error: 2.1079 - mean_squared_error: 8.2938 - val_loss: 2.4513 - val_mean_absolute_error: 2.4513 - val_mean_squared_error: 11.9051
# Epoch 9/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 2.0234 - mean_absolute_error: 2.0234 - mean_squared_error: 7.8439 - val_loss: 2.5510 - val_mean_absolute_error: 2.5510 - val_mean_squared_error: 9.4888
# Epoch 10/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 1.9692 - mean_absolute_error: 1.9692 - mean_squared_error: 7.5145 - val_loss: 4.7083 - val_mean_absolute_error: 4.7083 - val_mean_squared_error: 32.8752
# Epoch 11/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 1.9022 - mean_absolute_error: 1.9022 - mean_squared_error: 7.1667 - val_loss: 2.3530 - val_mean_absolute_error: 2.3530 - val_mean_squared_error: 9.7992
# Epoch 12/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 1.8411 - mean_absolute_error: 1.8411 - mean_squared_error: 6.7939 - val_loss: 2.4080 - val_mean_absolute_error: 2.4080 - val_mean_squared_error: 10.0326
# Epoch 13/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 1.7759 - mean_absolute_error: 1.7759 - mean_squared_error: 6.4525 - val_loss: 2.4441 - val_mean_absolute_error: 2.4441 - val_mean_squared_error: 10.5375
# Epoch 14/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 1.7052 - mean_absolute_error: 1.7052 - mean_squared_error: 6.0283 - val_loss: 2.5197 - val_mean_absolute_error: 2.5197 - val_mean_squared_error: 10.6653
# Epoch 15/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 1.6545 - mean_absolute_error: 1.6545 - mean_squared_error: 5.7613 - val_loss: 2.5199 - val_mean_absolute_error: 2.5199 - val_mean_squared_error: 12.4065
# Epoch 16/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 1.5965 - mean_absolute_error: 1.5965 - mean_squared_error: 5.4521 - val_loss: 2.8059 - val_mean_absolute_error: 2.8059 - val_mean_squared_error: 13.0249
# Epoch 17/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 1.5365 - mean_absolute_error: 1.5365 - mean_squared_error: 5.1506 - val_loss: 2.6550 - val_mean_absolute_error: 2.6550 - val_mean_squared_error: 10.1097
# Epoch 18/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 1.4852 - mean_absolute_error: 1.4852 - mean_squared_error: 4.8737 - val_loss: 2.3471 - val_mean_absolute_error: 2.3471 - val_mean_squared_error: 10.1654
# Epoch 19/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 1.4198 - mean_absolute_error: 1.4198 - mean_squared_error: 4.5713 - val_loss: 3.1985 - val_mean_absolute_error: 3.1985 - val_mean_squared_error: 16.6061
# Epoch 20/20
# 22500/22500 [==============================] - 23s 1ms/step - loss: 1.3715 - mean_absolute_error: 1.3715 - mean_squared_error: 4.3087 - val_loss: 2.6484 - val_mean_absolute_error: 2.6484 - val_mean_squared_error: 11.5208
