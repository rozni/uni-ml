# %%
VOCABULARY_SIZE = 4095
VALIDATION_SPLIT = 0.25

# %%
# basic imports
import os

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras import layers

from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
# a NLP library
# get pretrained model with embeddings and load

# if GPU is on, Internet connection is needed in Kaggle Kernels!
# !python -m spacy download en_core_web_lg

import spacy
nlp = spacy.load('en_core_web_lg')
# Out:
# Requirement already satisfied: en_core_web_lg==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.0.0/en_core_web_lg-2.0.0.tar.gz#egg=en_core_web_lg==2.0.0 in /usr/lib/python3.7/site-packages (2.0.0)
#
#     Creating a shortcut link for 'en' didn't work (maybe you don't have
#     admin permissions?), but you can still load the model via its full
#     package name: nlp = spacy.load('{name}')
#     Download successful but linking failed

# %%
### plotting ###
# prettier and larger basic graphs
sns.set(rc={
    'figure.figsize':(18,8),
    'axes.titlesize':14,
})

### pandas ###
# no need to see many decimal places and makes nicer horizontal fits :-)
pd.options.display.float_format = '{:.3f}'.format
# pd.options.display.precision = 3
# make the tables more compact vertically, too
pd.options.display.max_rows = 20

### numpy ###
# same as for pandas - max. 3 decimal places
np.set_printoptions(formatter={'float_kind':'{:.3f}'.format})
# np.set_printoptions(precision=3)

# %%
print(os.listdir("../input"))
# Out:
# ['drugsComTrain_raw.csv', 'drugsComTest_raw.csv']

# %%
reviews_df = pd.read_csv('../input/drugsComTrain_raw.csv')
reviews_df
# Out:
#         uniqueID       drugName                      condition  \
# 121042    151370      OxyContin                           Pain
# 22563      96834         Ambien                       Insomnia
# 1953      187777  Dexamethasone                         Asthma
# 15706     179306     Olanzapine        Schizoaffective Disorde
# 148496     41529        Aubagio             Multiple Sclerosis
# 109551    189909        Chantix              Smoking Cessation
# 66164      50838   Azithromycin            Chlamydia Infection
# 80491      70328         Zofran                Nausea/Vomiting
# 35807      51838    Ustekinumab                      Psoriasis
# 152970     98107      Nexplanon                  Birth Control
# ...          ...            ...                            ...
# 39079     139401    Armodafinil                     Depression
# 132919     91906         Lyrica               Neuropathic Pain
# 139762    219169   Zovia 1 / 35                  Birth Control
# 133036    205597        Pristiq                        Anxiety
# 108642    139142    Phentermine                    Weight Loss
# 61743     147566     Alprazolam                        Anxiety
# 67407     171661     Wellbutrin                     Depression
# 84368     148951         Mirena      Abnormal Uterine Bleeding
# 158163    164534     Diclofenac                           Pain
# 131661     22552         Pylera  Helicobacter Pylori Infection
#
#                                                    review  rating       date  \
# 121042  "I was recently prescribed this medication and...       9   6-Mar-08
# 22563   "I have had good luck with this drug.  Diag wi...       9  17-Jun-17
# 1953    "Used periodically when other meds aren&#039;t...       8  28-Nov-13
# 15706   "Zyprexa- It is not a sedating medicine at all...       5   1-Dec-14
# 148496  "As soon as I began taking this medicine, my v...       2   7-Jul-15
# 109551  "I am starting week 4 on Chantix. I smoked for...       3  26-May-08
# 66164   "This is the second time I&#039;ve had to take...      10   6-Aug-17
# 80491   "I take several medications for treatment of A...      10  29-Jan-15
# 35807   "I have had servere psoriasis for 15 years I a...       9   5-Aug-15
# 152970  "No periods in three years. Doctor said this i...      10   5-Aug-15
# ...                                                   ...     ...        ...
# 39079   "I found Nuvigal to bring my life back from de...      10   4-Apr-13
# 132919  "I have had neuropathic spine pain  since 1984...      10   1-Jan-16
# 139762  "I started it freshman year of high school bec...      10  27-May-15
# 133036  "Made my anxiety worse. I could not have caffe...       1  14-Dec-11
# 108642  "I&#039;ve been taking Adipex for 2 weeks tomo...       9  16-Oct-08
# 61743   "I have cancer and this drug takes my mind of ...      10  16-Jun-09
# 67407   "After struggling with motivation and depressi...       9   8-Mar-10
# 84368   "I got the IUD put in at the end of June 2015....       2  15-Jan-16
# 158163  "I have heel spurs and find every few weeks th...      10  16-Jun-13
# 131661  "I was very hesitant to take this medicine bas...      10  14-Jan-17
#
#         usefulCount
# 121042          342
# 22563            20
# 1953             15
# 15706             9
# 148496           49
# 109551           78
# 66164            12
# 80491            41
# 35807            45
# 152970           13
# ...             ...
# 39079            51
# 132919           71
# 139762            3
# 133036            7
# 108642           17
# 61743            88
# 67407           127
# 84368            14
# 158163           44
# 131661           19
#
# [30000 rows x 7 columns]

# %%
reviews_test_df = pd.read_csv('../input/drugsComTest_raw.csv')
reviews_test_df
# Out:
#        uniqueID               drugName                     condition  \
# 0        163740            Mirtazapine                    Depression
# 1        206473             Mesalamine  Crohn's Disease, Maintenance
# 2        159672                Bactrim       Urinary Tract Infection
# 3         39293               Contrave                   Weight Loss
# 4         97768        Cyclafem 1 / 35                 Birth Control
# 5        208087                Zyclara                     Keratosis
# 6        215892                 Copper                 Birth Control
# 7        169852          Amitriptyline           Migraine Prevention
# 8         23295              Methadone             Opiate Withdrawal
# 9         71428                 Levora                 Birth Control
# ...         ...                    ...                           ...
# 53756    193118      Dextroamphetamine                          ADHD
# 53757     35261           Levofloxacin                    Bronchitis
# 53758    139347            Armodafinil                    Narcolepsy
# 53759     33495  Microgestin Fe 1 / 20                 Birth Control
# 53760    123432                   Apri                 Birth Control
# 53761    159999              Tamoxifen     Breast Cancer, Prevention
# 53762    140714           Escitalopram                       Anxiety
# 53763    130945         Levonorgestrel                 Birth Control
# 53764     47656             Tapentadol                          Pain
# 53765    113712              Arthrotec                      Sciatica
#
#                                                   review  rating       date  \
# 0      "I&#039;ve tried a few antidepressants over th...      10  28-Feb-12
# 1      "My son has Crohn&#039;s disease and has done ...       8  17-May-09
# 2                          "Quick reduction of symptoms"       9  29-Sep-17
# 3      "Contrave combines drugs that were used for al...       9   5-Mar-17
# 4      "I have been on this birth control for one cyc...       9  22-Oct-15
# 5      "4 days in on first 2 weeks.  Using on arms an...       4   3-Jul-14
# 6      "I&#039;ve had the copper coil for about 3 mon...       6   6-Jun-16
# 7      "This has been great for me. I&#039;ve been on...       9  21-Apr-09
# 8      "Ive been on Methadone for over ten years and ...       7  18-Oct-16
# 9      "I was on this pill for almost two years. It d...       2  16-Apr-11
# ...                                                  ...     ...        ...
# 53756  "Treatment for ADHD save my life. Don&#039;t b...      10  15-Nov-15
# 53757  "This is my 3rd time taking this medicine. Fir...      10  26-Oct-14
# 53758  "This medicine kept me from sleeping the whole...       1  30-Sep-14
# 53759  "I was on Microgestin for about 3 years. Over ...       6   1-Aug-14
# 53760  "I started taking Apri about 7 months ago. My ...       9  25-Aug-10
# 53761  "I have taken Tamoxifen for 5 years. Side effe...      10  13-Sep-14
# 53762  "I&#039;ve been taking Lexapro (escitaploprgra...       9   8-Oct-16
# 53763  "I&#039;m married, 34 years old and I have no ...       8  15-Nov-10
# 53764  "I was prescribed Nucynta for severe neck/shou...       1  28-Nov-11
# 53765                                      "It works!!!"       9  13-Sep-09
#
#        usefulCount
# 0               22
# 1               17
# 2                3
# 3               35
# 4                4
# 5               13
# 6                1
# 7               32
# 8               21
# 9                3
# ...            ...
# 53756           36
# 53757           29
# 53758           18
# 53759           15
# 53760           18
# 53761           43
# 53762           11
# 53763            7
# 53764           20
# 53765           46
#
# [53766 rows x 7 columns]

# %% [markdown]
# The reviews are quite raw (containing unhealthy things for tokenizers such as `&#039;` *- an HTML code for apostrophe*),
# I will quickly cook them a bit before progressing further...

# %%
## sanitizing review text

from html import unescape

def clean_review(text):
    """Replace HTML escaped characters
    and strip outer quotes and spaces"""
    return unescape(text.strip(' "\'')).replace('\r', ' ').replace('\n', ' ').replace('\ufeff1', '')

reviews_df.review = reviews_df.review.apply(clean_review)
reviews_test_df.review = reviews_test_df.review.apply(clean_review)

# %% [markdown]
# Today we have a soup made mostly with the following ingredients

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(
    width=1000,
    height=500,
    random_state=hash('yummy'),
    max_font_size=110
)
wordcloud.generate('\n'.join(reviews_df.review))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
del wordcloud

# %%
## lemmatizing review text

def text2lexemes(text):
    """tokenize -> lemmatize"""
    
    tokens = nlp(
        # also split on "/"
        text.replace('/', ' / '),
        # we only need tokenizer and lemmas, so disable the rest
        disable=['tagger', 'parser', 'ner']
    )
    
    lexemes = []
    for token in tokens:
        
        if nlp.vocab[token.lemma_.lower()].has_vector:
            lexeme = token.lemma_.lower()
        elif nlp.vocab[token.norm_.lower()].has_vector:
            lexeme = token.norm_.lower()
        else:
            lexeme = token.lower_
        
        lexemes.append(lexeme)
        
    return lexemes

reviews_word_seq = [text2lexemes(review) for review in reviews_df.review]

# %%
# vocabulary map
# count occurences of each word
word_count = {}
for lemmas in reviews_word_seq:
    for lemma in lemmas:
        word_count[lemma] = word_count.get(lemma, 0) + 1
word_count = dict(sorted(word_count.items(), key=lambda pair: pair[1], reverse=True))

# %%
word_count
# Out:
# {'.': 160263,
#  'i': 159602,
#  'be': 109075,
#  'have': 84881,
#  'and': 80098,
#  ',': 78983,
#  'the': 75570,
#  'a': 67980,
#  'to': 59990,
#  'it': 59066,
#  'my': 53889,
#  'for': 37573,
#  'not': 34724,
#  'of': 31771,
#  ' ': 31751,
#  'this': 26557,
#  'on': 25540,
#  'take': 24658,
#  'in': 23486,
#  'but': 22987,
#  'me': 21443,
#  'that': 20977,
#  'do': 20773,
#  'with': 19545,
#  'day': 18224,
#  '!': 17112,
#  'get': 16368,
#  'so': 15348,
#  'feel': 13293,
#  'month': 13083,
#  'go': 12249,
#  'year': 12197,
#  'at': 11972,
#  'after': 11586,
#  'much': 11468,
#  'no': 11105,
#  'work': 11068,
#  'week': 10783,
#  'effect': 10343,
#  'start': 10297,
#  'now': 10282,
#  'about': 10256,
#  'side': 9962,
#  'can': 9876,
#  'time': 9561,
#  'all': 9179,
#  'pain': 9044,
#  '2': 8947,
#  'mg': 8577,
#  ')': 8502,
#  '-': 8438,
#  'first': 8409,
#  '(': 8220,
#  'you': 8077,
#  'only': 8006,
#  'like': 7948,
#  'up': 7819,
#  'would': 7638,
#  'pill': 7637,
#  'very': 7465,
#  'just': 7404,
#  'period': 7381,
#  'use': 7336,
#  '3': 7193,
#  'or': 7167,
#  'out': 7139,
#  'from': 7138,
#  'good': 7077,
#  'when': 7001,
#  'because': 6482,
#  'will': 6470,
#  'if': 6440,
#  'try': 6353,
#  'help': 6309,
#  'make': 6143,
#  'medication': 5955,
#  'one': 5885,
#  'back': 5863,
#  'well': 5855,
#  'doctor': 5669,
#  '/': 5502,
#  'little': 5371,
#  'also': 5322,
#  'then': 5206,
#  'weight': 5072,
#  'before': 5068,
#  'which': 4898,
#  'since': 4814,
#  'medicine': 4776,
#  'life': 4775,
#  'give': 4716,
#  'bad': 4677,
#  'experience': 4650,
#  'still': 4602,
#  'stop': 4582,
#  'other': 4487,
#  'sleep': 4464,
#  'really': 4453,
#  'off': 4450,
#  'any': 4424,
#  'anxiety': 4418,
#  'think': 4332,
#  'some': 4305,
#  'over': 4263,
#  'control': 4173,
#  'last': 4148,
#  'never': 4101,
#  'hour': 4070,
#  'they': 4056,
#  '4': 4022,
#  'two': 4011,
#  'than': 3988,
#  '5': 3897,
#  'say': 3881,
#  '"': 3847,
#  'night': 3825,
#  'every': 3818,
#  'even': 3803,
#  'gain': 3795,
#  '10': 3717,
#  'great': 3696,
#  'cramp': 3549,
#  'few': 3545,
#  'drug': 3533,
#  'long': 3420,
#  'wrong': 3407,
#  'dose': 3395,
#  'again': 3318,
#  'by': 3297,
#  'thing': 3285,
#  '1': 3254,
#  'ago': 3219,
#  'lose': 3185,
#  'birth': 3119,
#  'acne': 3111,
#  '6': 3077,
#  'prescribe': 3076,
#  'depression': 2990,
#  'know': 2952,
#  'bleed': 2902,
#  'what': 2882,
#  'problem': 2880,
#  'come': 2880,
#  'see': 2880,
#  'there': 2877,
#  'almost': 2837,
#  'eat': 2811,
#  'want': 2802,
#  'down': 2780,
#  'change': 2779,
#  'severe': 2768,
#  '  ': 2754,
#  'find': 2723,
#  'put': 2715,
#  'lot': 2710,
#  'headache': 2706,
#  'recommend': 2678,
#  'mood': 2610,
#  'he': 2599,
#  'need': 2553,
#  'your': 2537,
#  'far': 2487,
#  'skin': 2427,
#  'notice': 2402,
#  '...': 2398,
#  'ever': 2357,
#  '&': 2333,
#  'nothing': 2330,
#  'nausea': 2316,
#  'tell': 2316,
#  'away': 2293,
#  'sex': 2280,
#  'symptom': 2267,
#  'too': 2221,
#  'normal': 2154,
#  'keep': 2097,
#  'while': 2076,
#  'old': 2053,
#  'however': 2051,
#  'without': 2048,
#  'body': 2032,
#  'morning': 2029,
#  'love': 2015,
#  'late': 1997,
#  '20': 1970,
#  'clear': 1966,
#  'seem': 1966,
#  'spot': 1950,
#  'its': 1938,
#  'many': 1922,
#  'them': 1922,
#  'until': 1921,
#  'within': 1920,
#  'low': 1903,
#  'how': 1889,
#  'next': 1882,
#  'once': 1881,
#  'happy': 1849,
#  'always': 1845,
#  'suffer': 1843,
#  'hope': 1831,
#  'switch': 1802,
#  'horrible': 1786,
#  'doe': 1780,
#  'due': 1753,
#  'through': 1750,
#  'stomach': 1748,
#  'pound': 1748,
#  'around': 1739,
#  'able': 1733,
#  'may': 1730,
#  'three': 1712,
#  'blood': 1710,
#  'begin': 1699,
#  'right': 1699,
#  'myself': 1698,
#  'migraine': 1684,
#  'light': 1682,
#  'increase': 1675,
#  '7': 1664,
#  'she': 1663,
#  'finally': 1657,
#  'high': 1642,
#  '8': 1641,
#  'way': 1615,
#  'wake': 1603,
#  'could': 1603,
#  'different': 1599,
#  'during': 1589,
#  'issue': 1586,
#  'cause': 1577,
#  'daily': 1569,
#  '30': 1565,
#  'drive': 1560,
#  'who': 1540,
#  'though': 1537,
#  '..': 1535,
#  'drink': 1530,
#  'same': 1529,
#  'sure': 1522,
#  'become': 1515,
#  'we': 1513,
#  'another': 1511,
#  'people': 1505,
#  '   ': 1480,
#  'anything': 1479,
#  'read': 1466,
#  'attack': 1465,
#  'swing': 1463,
#  'something': 1445,
#  'review': 1437,
#  'completely': 1435,
#  'couple': 1413,
#  'dry': 1411,
#  'result': 1402,
#  'everything': 1396,
#  'half': 1386,
#  ':': 1377,
#  'end': 1373,
#  'lb': 1365,
#  'into': 1365,
#  'panic': 1362,
#  'face': 1360,
#  'bite': 1360,
#  'new': 1359,
#  'heavy': 1350,
#  'minute': 1333,
#  'worth': 1319,
#  'terrible': 1297,
#  '15': 1296,
#  'tire': 1293,
#  'break': 1279,
#  'infection': 1268,
#  'stay': 1263,
#  'decide': 1252,
#  'leave': 1251,
#  'loss': 1250,
#  '?': 1242,
#  'relief': 1234,
#  'appetite': 1229,
#  'painful': 1227,
#  'today': 1222,
#  'shoot': 1220,
#  'extremely': 1219,
#  'past': 1216,
#  'pretty': 1215,
#  'actually': 1200,
#  'effective': 1190,
#  'pregnant': 1188,
#  'where': 1186,
#  'continue': 1173,
#  'definitely': 1161,
#  'water': 1148,
#  'look': 1141,
#  'bed': 1137,
#  'hard': 1121,
#  'twice': 1110,
#  'sometimes': 1098,
#  'full': 1096,
#  'depress': 1081,
#  'diagnose': 1058,
#  ';': 1057,
#  'meds': 1053,
#  '100': 1051,
#  'treatment': 1041,
#  '50': 1036,
#  'worry': 1028,
#  'several': 1019,
#  'product': 1011,
#  'should': 1011,
#  '%': 1006,
#  'enough': 995,
#  'burn': 994,
#  'everyone': 994,
#  'happen': 990,
#  'energy': 988,
#  'fall': 987,
#  'mouth': 985,
#  'dosage': 980,
#  'insurance': 978,
#  'fine': 976,
#  'big': 970,
#  'pressure': 966,
#  'taste': 965,
#  'point': 963,
#  'food': 962,
#  'anyone': 960,
#  'live': 956,
#  'soon': 951,
#  'head': 946,
#  'sick': 941,
#  '12': 937,
#  'negative': 932,
#  'small': 914,
#  'patch': 913,
#  'free': 907,
#  'mild': 906,
#  'else': 904,
#  'leg': 901,
#  'insert': 901,
#  '9': 899,
#  'insertion': 896,
#  'deal': 893,
#  'difference': 893,
#  'both': 891,
#  'cry': 891,
#  'already': 885,
#  'wait': 883,
#  '25': 883,
#  'hurt': 878,
#  'level': 872,
#  'recently': 866,
#  'remove': 854,
#  'extreme': 851,
#  'sweat': 851,
#  'smoke': 848,
#  'usually': 842,
#  'absolutely': 839,
#  'maybe': 839,
#  'overall': 834,
#  'short': 833,
#  'amaze': 833,
#  'awful': 831,
#  '40': 830,
#  'heart': 828,
#  'injection': 828,
#  'etc': 825,
#  'med': 824,
#  'test': 815,
#  'dr': 814,
#  'exercise': 813,
#  'diarrhea': 808,
#  'her': 806,
#  'plan': 805,
#  'breast': 805,
#  'per': 801,
#  'insomnia': 793,
#  'hair': 791,
#  'easy': 789,
#  'whole': 789,
#  'muscle': 786,
#  'disorder': 785,
#  'immediately': 783,
#  'eye': 777,
#  'reason': 777,
#  'each': 776,
#  'affect': 775,
#  '$': 771,
#  'as': 770,
#  'ask': 762,
#  'person': 759,
#  'quit': 758,
#  'call': 756,
#  'surgery': 753,
#  'yet': 753,
#  'here': 749,
#  'fatigue': 749,
#  'cold': 748,
#  'along': 747,
#  'pregnancy': 747,
#  'had': 741,
#  'major': 740,
#  'miracle': 740,
#  'diet': 740,
#  "'": 739,
#  'stress': 738,
#  'anymore': 737,
#  'pack': 731,
#  'although': 731,
#  'walk': 728,
#  'job': 725,
#  'let': 724,
#  'bloat': 723,
#  'vomit': 723,
#  'zoloft': 721,
#  '24': 720,
#  'thank': 718,
#  'hand': 718,
#  'positive': 717,
#  'itch': 714,
#  'nauseous': 709,
#  'sore': 709,
#  'early': 706,
#  'swell': 706,
#  'wonder': 701,
#  'cycle': 700,
#  'mirena': 699,
#  'constant': 695,
#  'fast': 692,
#  'thought': 688,
#  'crazy': 685,
#  'slight': 684,
#  'why': 682,
#  'yr': 677,
#  'such': 677,
#  'part': 675,
#  'believe': 670,
#  'please': 670,
#  'remember': 668,
#  'prescription': 666,
#  'chronic': 666,
#  'highly': 665,
#  'asleep': 663,
#  'decrease': 659,
#  'tablet': 659,
#  'pay': 654,
#  'reduce': 651,
#  'everyday': 648,
#  'wish': 646,
#  'mind': 641,
#  'follow': 638,
#  'improve': 638,
#  'cough': 636,
#  'stick': 635,
#  'lexapro': 632,
#  'regular': 631,
#  'wear': 630,
#  'his': 629,
#  'run': 629,
#  'constantly': 626,
#  'scare': 626,
#  'nexplanon': 626,
#  'drop': 621,
#  '     ': 619,
#  'was': 618,
#  'move': 616,
#  'add': 615,
#  'under': 614,
#  'stuff': 610,
#  'foot': 609,
#  'talk': 607,
#  'him': 606,
#  'arm': 606,
#  'cream': 605,
#  'home': 604,
#  'four': 603,
#  'school': 603,
#  'calm': 602,
#  'bc': 598,
#  'probably': 598,
#  'save': 596,
#  'doc': 594,
#  'cover': 593,
#  'hate': 592,
#  'place': 591,
#  'withdrawal': 591,
#  'started': 590,
#  'constipation': 589,
#  'okay': 588,
#  'hospital': 587,
#  'implant': 587,
#  '    ': 586,
#  'chest': 581,
#  'er': 578,
#  'dizziness': 578,
#  'either': 577,
#  'child': 576,
#  'quite': 575,
#  'turn': 568,
#  'hot': 567,
#  'super': 555,
#  'antibiotic': 554,
#  'reaction': 553,
#  'dizzy': 553,
#  'develope': 552,
#  'hormone': 550,
#  'finish': 549,
#  'husband': 548,
#  'improvement': 544,
#  'took': 543,
#  'miss': 542,
#  'emotional': 541,
#  'suggest': 540,
#  'care': 540,
#  'sugar': 537,
#  'age': 537,
#  'plus': 537,
#  'iud': 536,
#  'yes': 533,
#  'ache': 532,
#  'generic': 530,
#  '18': 530,
#  '....': 528,
#  'amount': 527,
#  '16': 526,
#  'function': 525,
#  'huge': 525,
#  'anxious': 524,
#  'weigh': 520,
#  'type': 520,
#  'realize': 520,
#  'healthy': 518,
#  'rest': 516,
#  'except': 516,
#  'post': 513,
#  'quickly': 512,
#  'xanax': 510,
#  'moody': 509,
#  'treat': 505,
#  'pass': 502,
#  'family': 501,
#  'trouble': 500,
#  '60': 499,
#  'return': 499,
#  'cymbalta': 495,
#  'luck': 494,
#  'bipolar': 492,
#  'focus': 491,
#  'brain': 490,
#  'literally': 488,
#  'cost': 485,
#  'baby': 484,
#  'knee': 480,
#  'implanon': 480,
#  'forget': 480,
#  'dream': 480,
#  'currently': 478,
#  'expect': 477,
#  'self': 477,
#  'friend': 476,
#  'form': 472,
#  '14': 472,
#  'wonderful': 471,
#  'kind': 471,
#  'cut': 470,
#  'kid': 469,
#  'struggle': 468,
#  'glad': 465,
#  'expensive': 464,
#  'boyfriend': 463,
#  'throw': 463,
#  'strong': 463,
#  'area': 459,
#  'hear': 459,
#  'entire': 458,
#  'totally': 458,
#  'neck': 457,
#  '2015': 456,
#  'between': 456,
#  'depo': 455,
#  'b': 455,
#  'guess': 453,
#  'son': 451,
#  'straight': 451,
#  '2nd': 448,
#  'instead': 446,
#  'especially': 446,
#  'honestly': 446,
#  'must': 444,
#  'woman': 443,
#  'suppose': 443,
#  'size': 442,
#  'barely': 438,
#  'often': 436,
#  'fact': 436,
#  'effexor': 436,
#  'term': 436,
#  'joint': 435,
#  'non': 435,
#  'red': 434,
#  'brand': 434,
#  '3rd': 433,
#  'god': 433,
#  'hungry': 432,
#  'bowel': 432,
#  'rate': 431,
#  'dr.': 430,
#  'rather': 430,
#  'slowly': 429,
#  'breakout': 428,
#  'include': 427,
#  'mean': 426,
#  'prior': 423,
#  'seizure': 421,
#  'someone': 419,
#  '11': 418,
#  'prozac': 417,
#  'six': 416,
#  'sleepy': 415,
#  'anti': 415,
#  'nearly': 413,
#  'active': 412,
#  'apply': 411,
#  'close': 410,
#  'consider': 410,
#  'bathroom': 410,
#  'works': 409,
#  'skyla': 409,
#  'been': 408,
#  'antidepressant': 406,
#  'sit': 406,
#  'condition': 403,
#  'subside': 403,
#  'their': 401,
#  'course': 400,
#  '150': 399,
#  'craving': 398,
#  'numb': 398,
#  'prevent': 395,
#  'real': 395,
#  'wellbutrin': 394,
#  '1st': 393,
#  'paxil': 392,
#  '200': 391,
#  'yeast': 390,
#  'rid': 389,
#  'yesterday': 389,
#  'unfortunately': 386,
#  'buy': 385,
#  'pimple': 384,
#  'upset': 384,
#  'case': 383,
#  'check': 380,
#  'kick': 380,
#  'hr': 377,
#  'hopefully': 376,
#  'none': 376,
#  'health': 374,
#  'five': 374,
#  'intense': 374,
#  'rash': 373,
#  'weird': 370,
#  'nerve': 369,
#  'minor': 365,
#  'throat': 364,
#  'total': 363,
#  'awake': 362,
#  'breathe': 362,
#  'normally': 360,
#  'celexa': 360,
#  '75': 360,
#  'sinus': 359,
#  'allow': 358,
#  'slow': 357,
#  'relieve': 354,
#  'eventually': 354,
#  'irregular': 353,
#  'uncomfortable': 351,
#  'yaz': 351,
#  'system': 350,
#  'nose': 350,
#  '300': 349,
#  'serious': 349,
#  'flash': 348,
#  'meal': 348,
#  'mention': 347,
#  'min': 347,
#  'episode': 345,
#  'slightly': 344,
#  'easily': 344,
#  'relax': 343,
#  'zero': 343,
#  'sensitive': 341,
#  'nightmare': 340,
#  'seroquel': 339,
#  'write': 337,
#  'cancer': 337,
#  'clean': 336,
#  'suicidal': 336,
#  'procedure': 334,
#  'fibromyalgia': 334,
#  'nervous': 333,
#  'handle': 333,
#  'adhd': 333,
#  'single': 332,
#  'lack': 332,
#  'show': 331,
#  'adjust': 330,
#  'hit': 330,
#  'allergy': 329,
#  'benefit': 329,
#  '13': 328,
#  'usual': 327,
#  'difficult': 327,
#  'patient': 327,
#  '2016': 326,
#  'research': 326,
#  'bottle': 326,
#  'option': 325,
#  'combination': 325,
#  'story': 325,
#  'occasional': 324,
#  'vision': 323,
#  '90': 322,
#  'irritable': 322,
#  'disease': 320,
#  'own': 320,
#  'enjoy': 320,
#  'annoy': 319,
#  'libido': 319,
#  'dermatologist': 319,
#  'itchy': 318,
#  'disappear': 318,
#  'loestrin': 318,
#  'moderate': 317,
#  'sprintec': 317,
#  'perfect': 316,
#  'truly': 316,
#  'possible': 316,
#  'complete': 316,
#  'allergic': 315,
#  'send': 315,
#  'concern': 313,
#  'angry': 313,
#  'large': 313,
#  'cure': 312,
#  'stand': 311,
#  'syndrome': 310,
#  'nuvaring': 310,
#  'p.m.': 309,
#  'flu': 308,
#  'minimal': 307,
#  '17': 305,
#  'lyrica': 305,
#  'chantix': 304,
#  'bring': 304,
#  'sad': 303,
#  '--': 303,
#  'breath': 303,
#  'grow': 302,
#  'march': 302,
#  'feeling': 301,
#  'daughter': 301,
#  'throughout': 301,
#  'ambien': 301,
#  'mostly': 301,
#  'arthritis': 299,
#  'miserable': 299,
#  'adderall': 298,
#  'spasm': 298,
#  'spend': 298,
#  'pharmacy': 297,
#  'hell': 297,
#  'social': 294,
#  '80': 293,
#  'condom': 292,
#  'state': 292,
#  'suboxone': 292,
#  'complaint': 290,
#  'sexual': 289,
#  'basically': 289,
#  'tri': 289,
#  'lie': 289,
#  'unbearable': 288,
#  'appointment': 287,
#  'bone': 286,
#  'fe': 285,
#  'klonopin': 285,
#  'fear': 283,
#  'afraid': 283,
#  'movement': 283,
#  'price': 282,
#  'inside': 282,
#  'shoulder': 282,
#  'bedtime': 281,
#  '      ': 281,
#  'our': 281,
#  'discomfort': 280,
#  'x': 280,
#  'unable': 280,
#  'accutane': 280,
#  'lo': 280,
#  'awesome': 280,
#  'house': 278,
#  'quick': 278,
#  'went': 278,
#  'physical': 277,
#  'contrave': 277,
#  'lip': 277,
#  'ready': 277,
#  'bladder': 276,
#  'alcohol': 274,
#  'prep': 274,
#  'cyst': 274,
#  'mine': 274,
#  'anyway': 274,
#  'lamictal': 274,
#  'xr': 274,
#  'top': 273,
#  'method': 273,
#  'compare': 273,
#  'shake': 272,
#  'female': 272,
#  'process': 272,
#  'ibuprofen': 272,
#  'second': 271,
#  'fever': 270,
#  'manage': 270,
#  'initially': 270,
#  'shot': 269,
#  'ear': 269,
#  'figure': 269,
#  'cystic': 268,
#  '500': 268,
#  'vyvanse': 267,
#  'relationship': 266,
#  'discontinue': 266,
#  '45': 265,
#  'relate': 263,
#  'ring': 263,
#  'memory': 263,
#  'pristiq': 263,
#  'avoid': 262,
#  'idea': 262,
#  'pm': 262,
#  'breakthrough': 261,
#  'a.m.': 261,
#  'quality': 260,
#  'choice': 260,
#  'discharge': 258,
#  'uti': 257,
#  'flare': 257,
#  'middle': 257,
#  'emotion': 256,
#  'mix': 255,
#  'extra': 254,
#  'july': 253,
#  'update': 252,
#  'sample': 252,
#  'receive': 252,
#  'gel': 252,
#  'mental': 251,
#  'regulate': 251,
#  'money': 250,
#  'speak': 250,
#  'multiple': 250,
#  'comment': 248,
#  'watch': 248,
#  '2014': 248,
#  'race': 248,
#  'drowsy': 247,
#  'success': 247,
#  'understand': 247,
#  'hormonal': 247,
#  '19': 247,
#  '21': 246,
#  'open': 246,
#  'hardly': 245,
#  'general': 245,
#  'saver': 244,
#  'habit': 244,
#  'ten': 243,
#  'psychiatrist': 243,
#  'tramadol': 243,
#  'learn': 241,
#  'room': 241,
#  'kill': 240,
#  'otherwise': 240,
#  'noticeable': 239,
#  'best': 239,
#  'pms': 239,
#  'january': 238,
#  'fail': 238,
#  'chance': 238,
#  'damage': 238,
#  'previously': 238,
#  'disc': 237,
#  'freak': 236,
#  'therapy': 236,
#  'august': 236,
#  'hip': 235,
#  'tingle': 235,
#  'bump': 235,
#  'bother': 234,
#  'heal': 234,
#  'mess': 234,
#  'nurse': 234,
#  'chill': 234,
#  'matt': 234,
#  'flow': 234,
#  'wife': 233,
#  'helpful': 233,
#  'hold': 232,
#  'nice': 232,
#  'got': 232,
#  'tolerate': 232,
#  'oh': 231,
#  'company': 231,
#  'loose': 230,
#  'somewhat': 230,
#  'ortho': 230,
#  'tolerance': 229,
#  'lower': 229,
#  'suck': 228,
#  'cup': 228,
#  '28': 227,
#  'tomorrow': 227,
#  'visit': 227,
#  'wash': 227,
#  'us': 227,
#  'abilify': 226,
#  'deep': 225,
#  'chin': 225,
#  '4th': 224,
#  'name': 224,
#  'april': 224,
#  'exactly': 224,
#  'counter': 224,
#  'college': 223,
#  'erection': 223,
#  'psoriasis': 222,
#  'surprise': 222,
#  'tried': 222,
#  'june': 222,
#  'addict': 221,
#  'significant': 221,
#  'fight': 221,
#  'release': 221,
#  'unprotected': 220,
#  'wow': 220,
#  'tear': 220,
#  'alone': 220,
#  'decision': 220,
#  'tooth': 220,
#  'interest': 220,
#  'desire': 220,
#  'site': 220,
#  'die': 219,
#  'market': 219,
#  'force': 219,
#  'bp': 219,
#  'drowsiness': 218,
#  'did': 218,
#  'accident': 218,
#  'c': 218,
#  'asthma': 218,
#  'abdominal': 218,
#  'clot': 217,
#  'stone': 217,
#  'kidney': 217,
#  'december': 217,
#  'together': 216,
#  'wean': 216,
#  'concentrate': 216,
#  'risk': 216,
#  'gabapentin': 215,
#  'list': 215,
#  'share': 215,
#  'october': 215,
#  'smell': 214,
#  'previous': 213,
#  'acid': 213,
#  'careful': 212,
#  'situation': 211,
#  'november': 211,
#  'near': 210,
#  'set': 210,
#  'fix': 210,
#  'greatly': 210,
#  'line': 209,
#  'colonoscopy': 209,
#  'methadone': 209,
#  'young': 209,
#  'downside': 208,
#  'frequent': 208,
#  'initial': 208,
#  'weak': 207,
#  'dark': 207,
#  'liquid': 206,
#  'restless': 206,
#  ...}

# %%
## word sequence to integer sequences

vocab = list(word_count)[:VOCABULARY_SIZE]
word2index = {word:index for index, word in enumerate(vocab, start=1)}

reviews_seq = [
    [
        word2index.get(word, 0)
        for word in review
        # dismiss out-of-vocabulary words
        if word in word2index
    ]
    for review in reviews_word_seq
]

# %%
plt.title('Vocabulary Distribution')

wc_vals = list(word_count.values())

# plt.plot(vf, '.', label='Words how they came')
plt.plot(wc_vals, 'o', label='Lexeme count')
plt.plot(sum(wc_vals)-np.cumsum(wc_vals), '.', label='Uncaptured words')
plt.axvline(x=VOCABULARY_SIZE, color='yellowgreen', label=f'Current vocabulary size ({VOCABULARY_SIZE})')

plt.gca().set_yscale('log')
# plt.gca().set_xscale('log')

plt.legend()
plt.xlabel('Vocabulary Size')
plt.ylabel('Amount')

plt.show()

# %%
plt.title('Distribution of Review Lengths')

review_lengths = np.array([len(s) for s in reviews_seq])

sequence_cutoff_legth = int(np.quantile(review_lengths, 0.99))

sns.distplot(
    review_lengths,
    hist_kws=dict(label='Normalized histogram'),
    kde=True,
    kde_kws=dict(label='Kernel density'),
    rug=True,
    norm_hist=False,
    rug_kws=dict(color='orangered', label='Review'),
    axlabel='Sequence Length',
)
plt.axvline(
    x=sequence_cutoff_legth,
    color='yellowgreen',
    label=f'Sequence cutoff length ({sequence_cutoff_legth})'
)

plt.xlabel('Review Length')
plt.ylabel('Density')
plt.legend();

# %%
## pad the sequences

reviews_seq = keras.preprocessing.sequence.pad_sequences(
    reviews_seq,
    maxlen=sequence_cutoff_legth
)

# %%
## scale values

# range will be 0.1 - 1.0
# very easy interpretation for the MAE metrics
reviews_df.rating /= 10

# standard scaling
reviews_df.usefulCount += reviews_df.usefulCount.mean()
reviews_df.usefulCount /= reviews_df.usefulCount.std()

# %%
# plotting

def plot_history(history, skip_first_n_epochs=0):
    """Show information about the training"""
    
    # plot every train-valid metric pair separately
    for metric in history:
        if not metric.startswith('val_'):
            x = np.arange(len(history[metric]))+1

            y_train = history[metric][skip_first_n_epochs:]
            y_valid = history['val_'+metric][skip_first_n_epochs:]

            # make the plots
            plt.plot(x, y_train)
            plt.plot(x, y_valid)

            # add a legend
            plt.legend([metric, 'val_'+metric], fontsize='large')

            # title with min/max stats
            plt.title(
                f'{metric.upper()} - '
                f'min/max [train: {min(y_train):.3f}/{max(y_train):.3f}, '
                f'valid: {min(y_valid):.3f}/{max(y_valid):.3f}]'
            )
            
            # label and show
            plt.xlabel('epoch')
            plt.show()

# %%
embedding_weights = np.zeros((
    VOCABULARY_SIZE+1, # indices/hashes
    nlp.vocab.vectors_length # embedding dimmension
))
for word, index in word2index.items():
    embedding_weights[index] = nlp.vocab[word].vector

# %%
input_reviews = layers.Input(shape=(sequence_cutoff_legth,), dtype='int32')

branch_a = layers.Embedding(VOCABULARY_SIZE+1, output_dim=256)(input_reviews)
branch_a = layers.GaussianNoise(0.1)(branch_a)
branch_a = layers.CuDNNLSTM(128)(branch_a)
branch_a = layers.Dense(10, activation='relu')(branch_a)
branch_a = layers.BatchNormalization()(branch_a)
branch_a = layers.GaussianNoise(0.1)(branch_a)
model_output = layers.Dense(1, activation='sigmoid')(branch_a)

model_lstm = keras.models.Model(
    inputs=input_reviews,
    outputs=model_output,
)
model_lstm.summary()
# Out:
# WARNING:tensorflow:From /usr/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/martin/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 180)          0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 180, 300)     641400      input_1[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_2 (GaussianNoise (None, 180, 300)     0           embedding_2[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 180, 16)      14416       gaussian_noise_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 180, 16)      64          conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 90, 16)       0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 90, 32)       1568        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 90, 32)       128         conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 45, 32)       0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 45, 64)       6208        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 45, 64)       256         conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 22, 64)       0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 180, 256)     547328      input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 22, 128)      24704       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise (None, 180, 256)     0           embedding_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 22, 128)      512         conv1d_4[0][0]
# __________________________________________________________________________________________________
# cu_dnnlstm_1 (CuDNNLSTM)        (None, 128)          197632      gaussian_noise_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 128)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           1290        cu_dnnlstm_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           1290        global_max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 10)           40          dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 10)           40          dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 10)           0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 10)           0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 21)           0           dropout_1[0][0]
#                                                                  dropout_2[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           220         concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 10)           40          dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 10)           0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            11          dropout_3[0][0]
# ==================================================================================================
# Total params: 1,437,147
# Trainable params: 795,207
# Non-trainable params: 641,940
# __________________________________________________________________________________________________

# %%
input_reviews = layers.Input(shape=(sequence_cutoff_legth,), dtype='int32')

branch_b = layers.Embedding(
    *embedding_weights.shape,
    weights=[embedding_weights],
    input_length=sequence_cutoff_legth,
    trainable=True,
)(input_reviews)
branch_b = layers.GaussianNoise(0.1)(branch_b)
branch_b = layers.Conv1D(16, 3, padding='same', activation='relu')(branch_b)
branch_b = layers.BatchNormalization()(branch_b)
branch_b = layers.MaxPool1D(2)(branch_b)

branch_b = layers.Conv1D(32, 3, padding='same', activation='relu')(branch_b)
branch_b = layers.BatchNormalization()(branch_b)
branch_b = layers.MaxPool1D(2)(branch_b)

branch_b = layers.Conv1D(64, 3, padding='same', activation='relu')(branch_b)
branch_b = layers.BatchNormalization()(branch_b)
branch_b = layers.MaxPool1D(2)(branch_b)

branch_b = layers.Conv1D(128, 3, padding='same', activation='relu')(branch_b)
branch_b = layers.GlobalMaxPool1D()(branch_b)
branch_b = layers.BatchNormalization()(branch_b)
branch_b = layers.Dropout(0.2)(branch_b)

branch_b = layers.Dense(10, activation='relu')(branch_b)
branch_b = layers.BatchNormalization()(branch_b)
branch_b = layers.GaussianNoise(0.1)(branch_b)
model_output = layers.Dense(1, activation='sigmoid')(branch_b)

model_conv = keras.models.Model(
    inputs=input_reviews,
    outputs=model_output,
)
model_conv.summary()
# Out:
# WARNING:tensorflow:From /usr/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/martin/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 180)          0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 180, 300)     641400      input_1[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_2 (GaussianNoise (None, 180, 300)     0           embedding_2[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 180, 16)      14416       gaussian_noise_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 180, 16)      64          conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 90, 16)       0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 90, 32)       1568        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 90, 32)       128         conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 45, 32)       0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 45, 64)       6208        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 45, 64)       256         conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 22, 64)       0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 180, 256)     547328      input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 22, 128)      24704       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise (None, 180, 256)     0           embedding_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 22, 128)      512         conv1d_4[0][0]
# __________________________________________________________________________________________________
# cu_dnnlstm_1 (CuDNNLSTM)        (None, 128)          197632      gaussian_noise_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 128)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           1290        cu_dnnlstm_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           1290        global_max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 10)           40          dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 10)           40          dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 10)           0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 10)           0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 21)           0           dropout_1[0][0]
#                                                                  dropout_2[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           220         concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 10)           40          dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 10)           0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            11          dropout_3[0][0]
# ==================================================================================================
# Total params: 1,437,147
# Trainable params: 795,207
# Non-trainable params: 641,940
# __________________________________________________________________________________________________

# %%
input_reviews = layers.Input(shape=(sequence_cutoff_legth,), dtype='int32')
input_useful_count = layers.Input(shape=(1,))


model_top = layers.concatenate([branch_a, branch_b, input_useful_count])
model_top = layers.Dense(10, activation='relu')(model_top)
model_top = layers.BatchNormalization()(model_top)
model_output = layers.Dense(1, activation='sigmoid')(model_top)

model = keras.models.Model(
    inputs=[input_reviews, input_useful_count],
    outputs=model_output,
)
model.summary()
# Out:
# WARNING:tensorflow:From /usr/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/martin/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 180)          0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 180, 300)     641400      input_1[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_2 (GaussianNoise (None, 180, 300)     0           embedding_2[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 180, 16)      14416       gaussian_noise_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 180, 16)      64          conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 90, 16)       0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 90, 32)       1568        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 90, 32)       128         conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 45, 32)       0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 45, 64)       6208        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 45, 64)       256         conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 22, 64)       0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 180, 256)     547328      input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 22, 128)      24704       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise (None, 180, 256)     0           embedding_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 22, 128)      512         conv1d_4[0][0]
# __________________________________________________________________________________________________
# cu_dnnlstm_1 (CuDNNLSTM)        (None, 128)          197632      gaussian_noise_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 128)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           1290        cu_dnnlstm_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           1290        global_max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 10)           40          dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 10)           40          dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 10)           0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 10)           0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 21)           0           dropout_1[0][0]
#                                                                  dropout_2[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           220         concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 10)           40          dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 10)           0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            11          dropout_3[0][0]
# ==================================================================================================
# Total params: 1,437,147
# Trainable params: 795,207
# Non-trainable params: 641,940
# __________________________________________________________________________________________________

# %%
(
    y_train, y_valid,
    x1_train, x1_valid,
    x2_train, x2_valid,
) = train_test_split(
    reviews_df.rating.values, # y
    reviews_seq,
    reviews_df.usefulCount.values,
    # options
    test_size=VALIDATION_SPLIT,
    stratify=reviews_df.rating.values
)
x_train = [x1_train, x2_train]
x_valid = [x1_valid, x2_valid]

# %%
model.compile(
    optimizer='adam',
    loss='mae',
)

# %%
history = model.fit(
    x=x_train,
    y=y_train,
    validation_data=(x_valid, y_valid),
    batch_size=256,
    epochs=120,
    verbose=1,
    callbacks=[
        keras.callbacks.ModelCheckpoint(
            'model-epoch_{epoch:02d}-val_loss_{val_loss:.2f}.hdf5',
            monitor='val_loss',
            verbose=0,
            save_best_only=True,
            save_weights_only=False,
            mode='auto',
            period=1,
        ),
    ],
)

plot_history(history.history)
# Out:
# Train on 22500 samples, validate on 7500 samples
# Epoch 1/120
# 22500/22500 [==============================] - 9s 412us/step - loss: 0.1393 - val_loss: 0.1298
# Epoch 2/120
# 22500/22500 [==============================] - 9s 411us/step - loss: 0.1317 - val_loss: 0.1309
# Epoch 3/120
# 22500/22500 [==============================] - 9s 410us/step - loss: 0.1294 - val_loss: 0.1347
# Epoch 4/120
#  1280/22500 [>.............................] - ETA: 7s - loss: 0.1148
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-109-4feea3a94ac5> in <module>
#      14             save_weights_only=False,
#      15             mode='auto',
# ---> 16             period=1,
#      17         ),
#      18     ],
#
# ~/.local/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/.local/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /usr/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
x = [np.concatenate(z) for z in zip(x_train, x_valid)]
y = np.concatenate([y_train, y_valid])

color = ['#FFC07DA0']*len(y_train) + ['#988F32A0']*len(y_valid) # A276DD, 7347AD
y, (*x), color = zip(*sorted(zip(y, *x, color), key=lambda pair: pair[0]))
x = [np.asarray(i) for i in x]

yh = model.predict(x).ravel()

plt.scatter(range(len(y)), yh, c=color)
plt.scatter(range(len(y)), y, c='#73DA4D')
